# %% [markdown]
# # 심층 신경망 분류기 만들기
#
#
# ### _Objective_
# 1. 텐서플로우를 활용해 심층 신경망 분류기를 만들어봅니다.
# 2. 하이퍼파라미터를 결정하여 모델을 학습시켜봅니다.

# %%
# %matplotlib inline

import os
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from tensorflow.keras.utils import get_file

# %% [markdown]
# ### 예제 데이터 ) 암 환자 데이터 셋
#
# 나이와 종양크기를 바탕으로 암 환자의 종양이 양성인지 음성인지를 분류하는 데이터셋입니다.

# %%
fpath = get_file("cancer_dataset.csv",
                 "https://s3.ap-northeast-2.amazonaws.com/pai-datasets/alai-deeplearning/cancer_dataset.csv")
cancer_df = pd.read_csv(fpath)
X = cancer_df[['age','tumor_size']]
y = cancer_df["label"]

X = (X - X.min()) / (X.max() - X.min())

### 데이터 시각화
fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(1,1,1)

# 0: 정상
X[y==0].plot('age','tumor_size',ax=ax,legend=True,
                           kind='scatter',color='red')
# 1: 암환자
X[y==1].plot('age','tumor_size',ax=ax,legend=True,
                           kind='scatter',color='green')
plt.legend(['Normal','Cancer'])
plt.title("Cancer Or Not")
plt.show()

# %% [markdown]
# ## 1. Network Model 생성하기

# %% [markdown]
# 앞서 심층 신경망 모델의 개념을 배우며 텐서플로우를 이용해 간략하게 1번째 층의 유닛이 10개인 신경망 모델을 만들어봤습니다. 이번에는 1번째 층의 유닛이 200개인 신경망을 만들어봅시다.

# %%
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model

# %%
inputs = Input(2, name='x')
hidden1 = Dense(200, activation='relu', name='hidden1')(inputs)
output = Dense(1, activation='sigmoid', name='output')(hidden1)

model = Model(inputs, output, name='model')
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# x (InputLayer)               [(None, 2)]               0
# _________________________________________________________________
# hidden1 (Dense)              (None, 200)               600
# _________________________________________________________________
# output (Dense)               (None, 1)                 201
# =================================================================
# Total params: 801
# Trainable params: 801
# Non-trainable params: 0
# _________________________________________________________________

# %%
inputs = Input(2,name='x')

dense1 = Dense(200, activation='relu', name='dense_1',)
dense1_output = dense1(inputs)

dense2 = Dense(1, activation='sigmoid', name='dense_2')
dense2_output = dense2(dense1_output)

model = Model(inputs, dense2_output, name='model')

# %% [markdown]
# ## 2. 학습을 위해 Model 학습과정 설정하기
#
# keras에서는 `compile()`함수를 사용해 학습하기 전에 학습에 대한 설정을 수행합니다. (1) 최적화 함수, (2) 손실 함수, (3) 평가 지표 등을 결정하여 모델을 준비하는 방법을 알아보고, (4) 준비된 최적화 함수, 손실 함수, 평가지표 등으로 구성된 모델을 컴파일하는 방법을 알아봅시다.

# %% [markdown]
# ### (1) 최적화 함수 결정하기

# %% [markdown]
# 신경망 학습의 목적은 Loss Function의 결과값을 최소화하는 매개변수를 찾는 것입니다. 즉, 매개변수의 최적값을 찾는 것이 신경망 학습의 주된 문제이며 이러한 문제를 푸는 것을 **최적화**라고 합니다.최적화를 도와주는 함수로는 `SGD`, `momentum`, `NAG`, `Adagrad`, `RMSprop`, `Adam`등이 있습니다.
#
# keras에서는 아래와 같이 최적화 함수를 적용할 수 있습니다.

# %%
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.optimizers import RMSprop, Adam

# %%
optim = SGD(learning_rate=1e-2) # hyperparameter존재 = learning_rate, 너무 작지 않게 1e-5정도 -> auto는 연구하고 있지만.. 흠..
optim = RMSprop(learning_rate=1e-2, rho=0.9)
optim = Adam(learning_rate=1e-2, beta_1=0.9, beta_2=0.999)

# %% [markdown]
# 최적화 함수와 같이 직접 설정해주어야 하는 매개변수를 **하이퍼파라미터**라고 합니다. 하이퍼파라미터는 편향(bias)나 가중치(weight) 같은 신경망의 매개변수와는 성질이 다른 매개변수입니다. 신경망의 가중치는 훈련데이터와 학습 알고리즘에 의해서 자동으로 획득되는 매개변수인 반면, 최적화 함수와 같은 하이퍼파라미터는 사람이 직접 설정해야 하는 매개변수입니다. 일반적으로 이 하이퍼파라미터들은 여러 후보 값 중에서 시험을 통해 가장 잘 학습하는 값을 찾는 과정을 거쳐야 하는데, 이 과정을 하이퍼파라미터 최적화라고 합니다.

# %% [markdown]
# ### (2) 손실함수 결정하기

# %% [markdown]
# 손실함수에는 MSE외에 mean_absolute_error, categorical_crossentropy, binary_crossentropy등의 종류가 있습니다. MAE(mean_absolute_errer)는 MSE에서 제곱 대신 절댓값을 취한 함수로 특이점에 크게 영향을 받지 않는다는 장점이 있습니다. 보통 classification문제를 해결할 때 crossentropy 함수들을 사용합니다. <br>
#
# 아래의 표는 모델에 맞는 마지막 층의 활성화 함수와 손실 함수 선택을 정리한 표입니다.
#
# | 문제 유형 | 마지막 층의 활성화 함수 | 손실 함수 |
# | --- | --- | --- |
# | 이진 분류 | 시그모이드 | binary_crossentropy |
# | 단일 label 다중 분류 | 소프트맥스 | categorical_crossentropy |
# | 다중 label 다중 분류 | 시그모이드 | binary_crossentropy |
# | 임의 값에 대한 회귀 | 없음 | mse |
# | 0과 1 사이 값에 대한 회귀 | 시그모이드 | mse 또는 binary_crossentropy|

# %%
from tensorflow.keras.losses import BinaryCrossentropy

loss_func = BinaryCrossentropy()

# %% [markdown]
# ### (3)  평가 지표 결정하기

# %% [markdown]
# keras에서는 `tensorflow.keras.metrics`를 통해 평가 지표를 설정할 수 있습니다. 주요 평가지표로는 정확도를 나타내는 accuracy, binary_accuracy, categorical_accuracy, 상위 k개 예측값의 정확도를 나타내는 top_k_categorical_accuracy등이 있습니다.

# %%
from tensorflow.keras.metrics import BinaryAccuracy

# %%
metric_func = BinaryAccuracy()

# %% [markdown]
# ### (4) 모델 컴파일하기

# %% [markdown]
# keras의 `compile()` 과정에서 우리는 하이퍼파라미터인 최적화 함수, 손실함수, 평가 지표를 설정합니다. 이 과정에서 케라스의 기본 백엔드인 tensorflow에서는 최적화 함수, 손실함수, 평가 지표를 연결하여 계산 그래프 구성을 마무리하는 작업이 수행됩니다.

# %%
model.compile(optimizer=optim,
              loss=loss_func,
              metrics=[metric_func]) # model은 setting 완료

# %% [markdown]
# ## 3. Model 학습시키기
#
# keras에서는 `fit()`함수를 사용해 훈련셋을 이용하여 구성한 모델로 학습시킵니다.

# %% [markdown]
# `fit()` 함수의 주요 인자로는 epoch와 batch_size가 있습니다. 전체 훈련 데이터에 수행되는 각 반복을 **에포크(Epoch)**라고 합니다. 각 epoch마다 네트워크가 배치에서 손실에 대한 가중치의 그래디언트를 계산하고 그에 맞추어 가중치를 업데이트 합니다. batch_size는 기본 32로 설정되어 있습니다. 한 번에 32개의 데이터씩 처리한다는 의미입니다.

# %%
history = model.fit(X, y, epochs=1000, verbose=2)
# Out:
# Train on 100 samples
# Epoch 1/1000
# 100/100 - 0s - loss: 0.6716 - binary_accuracy: 0.6800
# Epoch 2/1000
# 100/100 - 0s - loss: 0.6065 - binary_accuracy: 0.7500
# Epoch 3/1000
# 100/100 - 0s - loss: 0.5453 - binary_accuracy: 0.8800
# Epoch 4/1000
# 100/100 - 0s - loss: 0.4891 - binary_accuracy: 0.8700
# Epoch 5/1000
# 100/100 - 0s - loss: 0.4261 - binary_accuracy: 0.9100
# Epoch 6/1000
# 100/100 - 0s - loss: 0.3852 - binary_accuracy: 0.8700
# Epoch 7/1000
# 100/100 - 0s - loss: 0.3344 - binary_accuracy: 0.8800
# Epoch 8/1000
# 100/100 - 0s - loss: 0.3042 - binary_accuracy: 0.9100
# Epoch 9/1000
# 100/100 - 0s - loss: 0.2810 - binary_accuracy: 0.9200
# Epoch 10/1000
# 100/100 - 0s - loss: 0.2765 - binary_accuracy: 0.8700
# Epoch 11/1000
# 100/100 - 0s - loss: 0.2492 - binary_accuracy: 0.8800
# Epoch 12/1000
# 100/100 - 0s - loss: 0.2332 - binary_accuracy: 0.9100
# Epoch 13/1000
# 100/100 - 0s - loss: 0.2246 - binary_accuracy: 0.9000
# Epoch 14/1000
# 100/100 - 0s - loss: 0.2175 - binary_accuracy: 0.9200
# Epoch 15/1000
# 100/100 - 0s - loss: 0.2122 - binary_accuracy: 0.9200
# Epoch 16/1000
# 100/100 - 0s - loss: 0.2120 - binary_accuracy: 0.9000
# Epoch 17/1000
# 100/100 - 0s - loss: 0.2219 - binary_accuracy: 0.9200
# Epoch 18/1000
# 100/100 - 0s - loss: 0.2220 - binary_accuracy: 0.9000
# Epoch 19/1000
# 100/100 - 0s - loss: 0.2495 - binary_accuracy: 0.8700
# Epoch 20/1000
# 100/100 - 0s - loss: 0.2177 - binary_accuracy: 0.8900
# Epoch 21/1000
# 100/100 - 0s - loss: 0.2031 - binary_accuracy: 0.9000
# Epoch 22/1000
# 100/100 - 0s - loss: 0.2358 - binary_accuracy: 0.9200
# Epoch 23/1000
# 100/100 - 0s - loss: 0.2112 - binary_accuracy: 0.9000
# Epoch 24/1000
# 100/100 - 0s - loss: 0.2161 - binary_accuracy: 0.8800
# Epoch 25/1000
# 100/100 - 0s - loss: 0.2189 - binary_accuracy: 0.8700
# Epoch 26/1000
# 100/100 - 0s - loss: 0.2090 - binary_accuracy: 0.9200
# Epoch 27/1000
# 100/100 - 0s - loss: 0.2291 - binary_accuracy: 0.9200
# Epoch 28/1000
# 100/100 - 0s - loss: 0.1973 - binary_accuracy: 0.9400
# Epoch 29/1000
# 100/100 - 0s - loss: 0.1970 - binary_accuracy: 0.9100
# Epoch 30/1000
# 100/100 - 0s - loss: 0.1944 - binary_accuracy: 0.9100
# Epoch 31/1000
# 100/100 - 0s - loss: 0.1931 - binary_accuracy: 0.9200
# Epoch 32/1000
# 100/100 - 0s - loss: 0.1916 - binary_accuracy: 0.9200
# Epoch 33/1000
# 100/100 - 0s - loss: 0.1908 - binary_accuracy: 0.9200
# Epoch 34/1000
# 100/100 - 0s - loss: 0.1907 - binary_accuracy: 0.9200
# Epoch 35/1000
# 100/100 - 0s - loss: 0.1902 - binary_accuracy: 0.9300
# Epoch 36/1000
# 100/100 - 0s - loss: 0.2039 - binary_accuracy: 0.9400
# Epoch 37/1000
# 100/100 - 0s - loss: 0.1979 - binary_accuracy: 0.9500
# Epoch 38/1000
# 100/100 - 0s - loss: 0.1947 - binary_accuracy: 0.9500
# Epoch 39/1000
# 100/100 - 0s - loss: 0.2095 - binary_accuracy: 0.9000
# Epoch 40/1000
# 100/100 - 0s - loss: 0.1993 - binary_accuracy: 0.8800
# Epoch 41/1000
# 100/100 - 0s - loss: 0.1899 - binary_accuracy: 0.9200
# Epoch 42/1000
# 100/100 - 0s - loss: 0.1904 - binary_accuracy: 0.9200
# Epoch 43/1000
# 100/100 - 0s - loss: 0.1935 - binary_accuracy: 0.9500
# Epoch 44/1000
# 100/100 - 0s - loss: 0.1942 - binary_accuracy: 0.9400
# Epoch 45/1000
# 100/100 - 0s - loss: 0.1987 - binary_accuracy: 0.9000
# Epoch 46/1000
# 100/100 - 0s - loss: 0.2608 - binary_accuracy: 0.8700
# Epoch 47/1000
# 100/100 - 0s - loss: 0.2289 - binary_accuracy: 0.8800
# Epoch 48/1000
# 100/100 - 0s - loss: 0.1907 - binary_accuracy: 0.9100
# Epoch 49/1000
# 100/100 - 0s - loss: 0.1980 - binary_accuracy: 0.9000
# Epoch 50/1000
# 100/100 - 0s - loss: 0.1973 - binary_accuracy: 0.9100
# Epoch 51/1000
# 100/100 - 0s - loss: 0.1901 - binary_accuracy: 0.9000
# Epoch 52/1000
# 100/100 - 0s - loss: 0.1919 - binary_accuracy: 0.9000
# Epoch 53/1000
# 100/100 - 0s - loss: 0.1962 - binary_accuracy: 0.9100
# Epoch 54/1000
# 100/100 - 0s - loss: 0.1845 - binary_accuracy: 0.9000
# Epoch 55/1000
# 100/100 - 0s - loss: 0.1872 - binary_accuracy: 0.9200
# Epoch 56/1000
# 100/100 - 0s - loss: 0.1898 - binary_accuracy: 0.9200
# Epoch 57/1000
# 100/100 - 0s - loss: 0.1820 - binary_accuracy: 0.9100
# Epoch 58/1000
# 100/100 - 0s - loss: 0.1932 - binary_accuracy: 0.9300
# Epoch 59/1000
# 100/100 - 0s - loss: 0.1999 - binary_accuracy: 0.9400
# Epoch 60/1000
# 100/100 - 0s - loss: 0.1922 - binary_accuracy: 0.9400
# Epoch 61/1000
# 100/100 - 0s - loss: 0.1804 - binary_accuracy: 0.9300
# Epoch 62/1000
# 100/100 - 0s - loss: 0.1826 - binary_accuracy: 0.9200
# Epoch 63/1000
# 100/100 - 0s - loss: 0.1833 - binary_accuracy: 0.9200
# Epoch 64/1000
# 100/100 - 0s - loss: 0.1800 - binary_accuracy: 0.9200
# Epoch 65/1000
# 100/100 - 0s - loss: 0.1829 - binary_accuracy: 0.9100
# Epoch 66/1000
# 100/100 - 0s - loss: 0.1952 - binary_accuracy: 0.9400
# Epoch 67/1000
# 100/100 - 0s - loss: 0.1881 - binary_accuracy: 0.9200
# Epoch 68/1000
# 100/100 - 0s - loss: 0.1798 - binary_accuracy: 0.9300
# Epoch 69/1000
# 100/100 - 0s - loss: 0.1818 - binary_accuracy: 0.9200
# Epoch 70/1000
# 100/100 - 0s - loss: 0.1810 - binary_accuracy: 0.9200
# Epoch 71/1000
# 100/100 - 0s - loss: 0.1865 - binary_accuracy: 0.9300
# Epoch 72/1000
# 100/100 - 0s - loss: 0.1839 - binary_accuracy: 0.9400
# Epoch 73/1000
# 100/100 - 0s - loss: 0.1793 - binary_accuracy: 0.9200
# Epoch 74/1000
# 100/100 - 0s - loss: 0.1842 - binary_accuracy: 0.9200
# Epoch 75/1000
# 100/100 - 0s - loss: 0.1813 - binary_accuracy: 0.9300
# Epoch 76/1000
# 100/100 - 0s - loss: 0.1856 - binary_accuracy: 0.9400
# Epoch 77/1000
# 100/100 - 0s - loss: 0.1754 - binary_accuracy: 0.9300
# Epoch 78/1000
# 100/100 - 0s - loss: 0.1809 - binary_accuracy: 0.9200
# Epoch 79/1000
# 100/100 - 0s - loss: 0.1780 - binary_accuracy: 0.9200
# Epoch 80/1000
# 100/100 - 0s - loss: 0.1792 - binary_accuracy: 0.9100
# Epoch 81/1000
# 100/100 - 0s - loss: 0.1755 - binary_accuracy: 0.9100
# Epoch 82/1000
# 100/100 - 0s - loss: 0.1747 - binary_accuracy: 0.9100
# Epoch 83/1000
# 100/100 - 0s - loss: 0.1761 - binary_accuracy: 0.9200
# Epoch 84/1000
# 100/100 - 0s - loss: 0.1849 - binary_accuracy: 0.9200
# Epoch 85/1000
# 100/100 - 0s - loss: 0.1952 - binary_accuracy: 0.9000
# Epoch 86/1000
# 100/100 - 0s - loss: 0.1875 - binary_accuracy: 0.9100
# Epoch 87/1000
# 100/100 - 0s - loss: 0.1769 - binary_accuracy: 0.9100
# Epoch 88/1000
# 100/100 - 0s - loss: 0.1750 - binary_accuracy: 0.9200
# Epoch 89/1000
# 100/100 - 0s - loss: 0.1666 - binary_accuracy: 0.9100
# Epoch 90/1000
# 100/100 - 0s - loss: 0.1912 - binary_accuracy: 0.9100
# Epoch 91/1000
# 100/100 - 0s - loss: 0.2025 - binary_accuracy: 0.9100
# Epoch 92/1000
# 100/100 - 0s - loss: 0.1797 - binary_accuracy: 0.9300
# Epoch 93/1000
# 100/100 - 0s - loss: 0.1809 - binary_accuracy: 0.9100
# Epoch 94/1000
# 100/100 - 0s - loss: 0.1797 - binary_accuracy: 0.9100
# Epoch 95/1000
# 100/100 - 0s - loss: 0.1748 - binary_accuracy: 0.9200
# Epoch 96/1000
# 100/100 - 0s - loss: 0.1759 - binary_accuracy: 0.9200
# Epoch 97/1000
# 100/100 - 0s - loss: 0.1711 - binary_accuracy: 0.9200
# Epoch 98/1000
# 100/100 - 0s - loss: 0.1794 - binary_accuracy: 0.9400
# Epoch 99/1000
# 100/100 - 0s - loss: 0.1829 - binary_accuracy: 0.9500
# Epoch 100/1000
# 100/100 - 0s - loss: 0.1772 - binary_accuracy: 0.9300
# Epoch 101/1000
# 100/100 - 0s - loss: 0.1727 - binary_accuracy: 0.9300
# Epoch 102/1000
# 100/100 - 0s - loss: 0.1670 - binary_accuracy: 0.9300
# Epoch 103/1000
# 100/100 - 0s - loss: 0.1680 - binary_accuracy: 0.9200
# Epoch 104/1000
# 100/100 - 0s - loss: 0.1696 - binary_accuracy: 0.9100
# Epoch 105/1000
# 100/100 - 0s - loss: 0.1671 - binary_accuracy: 0.9300
# Epoch 106/1000
# 100/100 - 0s - loss: 0.1655 - binary_accuracy: 0.9300
# Epoch 107/1000
# 100/100 - 0s - loss: 0.1647 - binary_accuracy: 0.9300
# Epoch 108/1000
# 100/100 - 0s - loss: 0.1692 - binary_accuracy: 0.9200
# Epoch 109/1000
# 100/100 - 0s - loss: 0.1656 - binary_accuracy: 0.9300
# Epoch 110/1000
# 100/100 - 0s - loss: 0.1801 - binary_accuracy: 0.9000
# Epoch 111/1000
# 100/100 - 0s - loss: 0.1796 - binary_accuracy: 0.9100
# Epoch 112/1000
# 100/100 - 0s - loss: 0.1607 - binary_accuracy: 0.9300
# Epoch 113/1000
# 100/100 - 0s - loss: 0.1661 - binary_accuracy: 0.9300
# Epoch 114/1000
# 100/100 - 0s - loss: 0.1690 - binary_accuracy: 0.9500
# Epoch 115/1000
# 100/100 - 0s - loss: 0.1790 - binary_accuracy: 0.9300
# Epoch 116/1000
# 100/100 - 0s - loss: 0.1666 - binary_accuracy: 0.9300
# Epoch 117/1000
# 100/100 - 0s - loss: 0.1694 - binary_accuracy: 0.9300
# Epoch 118/1000
# 100/100 - 0s - loss: 0.1779 - binary_accuracy: 0.9500
# Epoch 119/1000
# 100/100 - 0s - loss: 0.1689 - binary_accuracy: 0.9400
# Epoch 120/1000
# 100/100 - 0s - loss: 0.1761 - binary_accuracy: 0.9100
# Epoch 121/1000
# 100/100 - 0s - loss: 0.1704 - binary_accuracy: 0.9300
# Epoch 122/1000
# 100/100 - 0s - loss: 0.1636 - binary_accuracy: 0.9300
# Epoch 123/1000
# 100/100 - 0s - loss: 0.1633 - binary_accuracy: 0.9300
# Epoch 124/1000
# 100/100 - 0s - loss: 0.1611 - binary_accuracy: 0.9300
# Epoch 125/1000
# 100/100 - 0s - loss: 0.1642 - binary_accuracy: 0.9400
# Epoch 126/1000
# 100/100 - 0s - loss: 0.1624 - binary_accuracy: 0.9300
# Epoch 127/1000
# 100/100 - 0s - loss: 0.1620 - binary_accuracy: 0.9400
# Epoch 128/1000
# 100/100 - 0s - loss: 0.1687 - binary_accuracy: 0.9500
# Epoch 129/1000
# 100/100 - 0s - loss: 0.1606 - binary_accuracy: 0.9500
# Epoch 130/1000
# 100/100 - 0s - loss: 0.1627 - binary_accuracy: 0.9400
# Epoch 131/1000
# 100/100 - 0s - loss: 0.1581 - binary_accuracy: 0.9400
# Epoch 132/1000
# 100/100 - 0s - loss: 0.1614 - binary_accuracy: 0.9500
# Epoch 133/1000
# 100/100 - 0s - loss: 0.1599 - binary_accuracy: 0.9400
# Epoch 134/1000
# 100/100 - 0s - loss: 0.1612 - binary_accuracy: 0.9500
# Epoch 135/1000
# 100/100 - 0s - loss: 0.1612 - binary_accuracy: 0.9500
# Epoch 136/1000
# 100/100 - 0s - loss: 0.1561 - binary_accuracy: 0.9400
# Epoch 137/1000
# 100/100 - 0s - loss: 0.1597 - binary_accuracy: 0.9300
# Epoch 138/1000
# 100/100 - 0s - loss: 0.1632 - binary_accuracy: 0.9300
# Epoch 139/1000
# 100/100 - 0s - loss: 0.1616 - binary_accuracy: 0.9300
# Epoch 140/1000
# 100/100 - 0s - loss: 0.1787 - binary_accuracy: 0.9500
# Epoch 141/1000
# 100/100 - 0s - loss: 0.1696 - binary_accuracy: 0.9600
# Epoch 142/1000
# 100/100 - 0s - loss: 0.1674 - binary_accuracy: 0.9300
# Epoch 143/1000
# 100/100 - 0s - loss: 0.1808 - binary_accuracy: 0.9200
# Epoch 144/1000
# 100/100 - 0s - loss: 0.1758 - binary_accuracy: 0.9300
# Epoch 145/1000
# 100/100 - 0s - loss: 0.1693 - binary_accuracy: 0.9500
# Epoch 146/1000
# 100/100 - 0s - loss: 0.1646 - binary_accuracy: 0.9600
# Epoch 147/1000
# 100/100 - 0s - loss: 0.1657 - binary_accuracy: 0.9500
# Epoch 148/1000
# 100/100 - 0s - loss: 0.1588 - binary_accuracy: 0.9300
# Epoch 149/1000
# 100/100 - 0s - loss: 0.1586 - binary_accuracy: 0.9400
# Epoch 150/1000
# 100/100 - 0s - loss: 0.1734 - binary_accuracy: 0.9500
# Epoch 151/1000
# 100/100 - 0s - loss: 0.1820 - binary_accuracy: 0.9500
# Epoch 152/1000
# 100/100 - 0s - loss: 0.1724 - binary_accuracy: 0.9600
# Epoch 153/1000
# 100/100 - 0s - loss: 0.1630 - binary_accuracy: 0.9400
# Epoch 154/1000
# 100/100 - 0s - loss: 0.1620 - binary_accuracy: 0.9300
# Epoch 155/1000
# 100/100 - 0s - loss: 0.1655 - binary_accuracy: 0.9400
# Epoch 156/1000
# 100/100 - 0s - loss: 0.1591 - binary_accuracy: 0.9400
# Epoch 157/1000
# 100/100 - 0s - loss: 0.1571 - binary_accuracy: 0.9400
# Epoch 158/1000
# 100/100 - 0s - loss: 0.1635 - binary_accuracy: 0.9300
# Epoch 159/1000
# 100/100 - 0s - loss: 0.1577 - binary_accuracy: 0.9400
# Epoch 160/1000
# 100/100 - 0s - loss: 0.1554 - binary_accuracy: 0.9500
# Epoch 161/1000
# 100/100 - 0s - loss: 0.1554 - binary_accuracy: 0.9300
# Epoch 162/1000
# 100/100 - 0s - loss: 0.1604 - binary_accuracy: 0.9400
# Epoch 163/1000
# 100/100 - 0s - loss: 0.1651 - binary_accuracy: 0.9400
# Epoch 164/1000
# 100/100 - 0s - loss: 0.1604 - binary_accuracy: 0.9500
# Epoch 165/1000
# 100/100 - 0s - loss: 0.1648 - binary_accuracy: 0.9500
# Epoch 166/1000
# 100/100 - 0s - loss: 0.1767 - binary_accuracy: 0.9500
# Epoch 167/1000
# 100/100 - 0s - loss: 0.1609 - binary_accuracy: 0.9400
# Epoch 168/1000
# 100/100 - 0s - loss: 0.1528 - binary_accuracy: 0.9400
# Epoch 169/1000
# 100/100 - 0s - loss: 0.1660 - binary_accuracy: 0.9400
# Epoch 170/1000
# 100/100 - 0s - loss: 0.1648 - binary_accuracy: 0.9200
# Epoch 171/1000
# 100/100 - 0s - loss: 0.1614 - binary_accuracy: 0.9300
# Epoch 172/1000
# 100/100 - 0s - loss: 0.1595 - binary_accuracy: 0.9300
# Epoch 173/1000
# 100/100 - 0s - loss: 0.1558 - binary_accuracy: 0.9400
# Epoch 174/1000
# 100/100 - 0s - loss: 0.1695 - binary_accuracy: 0.9200
# Epoch 175/1000
# 100/100 - 0s - loss: 0.1599 - binary_accuracy: 0.9200
# Epoch 176/1000
# 100/100 - 0s - loss: 0.1538 - binary_accuracy: 0.9500
# Epoch 177/1000
# 100/100 - 0s - loss: 0.1548 - binary_accuracy: 0.9400
# Epoch 178/1000
# 100/100 - 0s - loss: 0.1562 - binary_accuracy: 0.9400
# Epoch 179/1000
# 100/100 - 0s - loss: 0.1598 - binary_accuracy: 0.9400
# Epoch 180/1000
# 100/100 - 0s - loss: 0.1538 - binary_accuracy: 0.9400
# Epoch 181/1000
# 100/100 - 0s - loss: 0.1521 - binary_accuracy: 0.9300
# Epoch 182/1000
# 100/100 - 0s - loss: 0.1659 - binary_accuracy: 0.9200
# Epoch 183/1000
# 100/100 - 0s - loss: 0.1771 - binary_accuracy: 0.9200
# Epoch 184/1000
# 100/100 - 0s - loss: 0.1563 - binary_accuracy: 0.9400
# Epoch 185/1000
# 100/100 - 0s - loss: 0.2178 - binary_accuracy: 0.9200
# Epoch 186/1000
# 100/100 - 0s - loss: 0.1764 - binary_accuracy: 0.9400
# Epoch 187/1000
# 100/100 - 0s - loss: 0.1541 - binary_accuracy: 0.9400
# Epoch 188/1000
# 100/100 - 0s - loss: 0.1780 - binary_accuracy: 0.8900
# Epoch 189/1000
# 100/100 - 0s - loss: 0.1465 - binary_accuracy: 0.9700
# Epoch 190/1000
# 100/100 - 0s - loss: 0.1995 - binary_accuracy: 0.9500
# Epoch 191/1000
# 100/100 - 0s - loss: 0.1778 - binary_accuracy: 0.9600
# Epoch 192/1000
# 100/100 - 0s - loss: 0.1500 - binary_accuracy: 0.9400
# Epoch 193/1000
# 100/100 - 0s - loss: 0.1661 - binary_accuracy: 0.9300
# Epoch 194/1000
# 100/100 - 0s - loss: 0.1600 - binary_accuracy: 0.9300
# Epoch 195/1000
# 100/100 - 0s - loss: 0.1605 - binary_accuracy: 0.9300
# Epoch 196/1000
# 100/100 - 0s - loss: 0.1767 - binary_accuracy: 0.9500
# Epoch 197/1000
# 100/100 - 0s - loss: 0.1575 - binary_accuracy: 0.9300
# Epoch 198/1000
# 100/100 - 0s - loss: 0.1716 - binary_accuracy: 0.9300
# Epoch 199/1000
# 100/100 - 0s - loss: 0.1653 - binary_accuracy: 0.9300
# Epoch 200/1000
# 100/100 - 0s - loss: 0.1609 - binary_accuracy: 0.9300
# Epoch 201/1000
# 100/100 - 0s - loss: 0.1714 - binary_accuracy: 0.9300
# Epoch 202/1000
# 100/100 - 0s - loss: 0.1549 - binary_accuracy: 0.9400
# Epoch 203/1000
# 100/100 - 0s - loss: 0.1567 - binary_accuracy: 0.9400
# Epoch 204/1000
# 100/100 - 0s - loss: 0.1572 - binary_accuracy: 0.9500
# Epoch 205/1000
# 100/100 - 0s - loss: 0.1451 - binary_accuracy: 0.9500
# Epoch 206/1000
# 100/100 - 0s - loss: 0.1800 - binary_accuracy: 0.9500
# Epoch 207/1000
# 100/100 - 0s - loss: 0.1829 - binary_accuracy: 0.9500
# Epoch 208/1000
# 100/100 - 0s - loss: 0.1643 - binary_accuracy: 0.9500
# Epoch 209/1000
# 100/100 - 0s - loss: 0.1565 - binary_accuracy: 0.9500
# Epoch 210/1000
# 100/100 - 0s - loss: 0.1507 - binary_accuracy: 0.9500
# Epoch 211/1000
# 100/100 - 0s - loss: 0.1495 - binary_accuracy: 0.9400
# Epoch 212/1000
# 100/100 - 0s - loss: 0.1485 - binary_accuracy: 0.9500
# Epoch 213/1000
# 100/100 - 0s - loss: 0.1546 - binary_accuracy: 0.9500
# Epoch 214/1000
# 100/100 - 0s - loss: 0.1501 - binary_accuracy: 0.9200
# Epoch 215/1000
# 100/100 - 0s - loss: 0.1700 - binary_accuracy: 0.9200
# Epoch 216/1000
# 100/100 - 0s - loss: 0.1723 - binary_accuracy: 0.9300
# Epoch 217/1000
# 100/100 - 0s - loss: 0.1591 - binary_accuracy: 0.9300
# Epoch 218/1000
# 100/100 - 0s - loss: 0.1540 - binary_accuracy: 0.9300
# Epoch 219/1000
# 100/100 - 0s - loss: 0.1505 - binary_accuracy: 0.9300
# Epoch 220/1000
# 100/100 - 0s - loss: 0.1465 - binary_accuracy: 0.9300
# Epoch 221/1000
# 100/100 - 0s - loss: 0.1491 - binary_accuracy: 0.9400
# Epoch 222/1000
# 100/100 - 0s - loss: 0.1503 - binary_accuracy: 0.9300
# Epoch 223/1000
# 100/100 - 0s - loss: 0.1454 - binary_accuracy: 0.9400
# Epoch 224/1000
# 100/100 - 0s - loss: 0.1454 - binary_accuracy: 0.9400
# Epoch 225/1000
# 100/100 - 0s - loss: 0.1484 - binary_accuracy: 0.9400
# Epoch 226/1000
# 100/100 - 0s - loss: 0.1472 - binary_accuracy: 0.9400
# Epoch 227/1000
# 100/100 - 0s - loss: 0.1457 - binary_accuracy: 0.9400
# Epoch 228/1000
# 100/100 - 0s - loss: 0.1451 - binary_accuracy: 0.9400
# Epoch 229/1000
# 100/100 - 0s - loss: 0.1471 - binary_accuracy: 0.9400
# Epoch 230/1000
# 100/100 - 0s - loss: 0.1505 - binary_accuracy: 0.9500
# Epoch 231/1000
# 100/100 - 0s - loss: 0.1602 - binary_accuracy: 0.9500
# Epoch 232/1000
# 100/100 - 0s - loss: 0.1558 - binary_accuracy: 0.9400
# Epoch 233/1000
# 100/100 - 0s - loss: 0.1713 - binary_accuracy: 0.9100
# Epoch 234/1000
# 100/100 - 0s - loss: 0.1469 - binary_accuracy: 0.9400
# Epoch 235/1000
# 100/100 - 0s - loss: 0.1577 - binary_accuracy: 0.9400
# Epoch 236/1000
# 100/100 - 0s - loss: 0.1585 - binary_accuracy: 0.9400
# Epoch 237/1000
# 100/100 - 0s - loss: 0.1467 - binary_accuracy: 0.9400
# Epoch 238/1000
# 100/100 - 0s - loss: 0.1467 - binary_accuracy: 0.9500
# Epoch 239/1000
# 100/100 - 0s - loss: 0.1460 - binary_accuracy: 0.9500
# Epoch 240/1000
# 100/100 - 0s - loss: 0.1437 - binary_accuracy: 0.9300
# Epoch 241/1000
# 100/100 - 0s - loss: 0.1479 - binary_accuracy: 0.9200
# Epoch 242/1000
# 100/100 - 0s - loss: 0.1490 - binary_accuracy: 0.9300
# Epoch 243/1000
# 100/100 - 0s - loss: 0.1495 - binary_accuracy: 0.9400
# Epoch 244/1000
# 100/100 - 0s - loss: 0.1438 - binary_accuracy: 0.9400
# Epoch 245/1000
# 100/100 - 0s - loss: 0.1450 - binary_accuracy: 0.9400
# Epoch 246/1000
# 100/100 - 0s - loss: 0.1466 - binary_accuracy: 0.9500
# Epoch 247/1000
# 100/100 - 0s - loss: 0.1446 - binary_accuracy: 0.9400
# Epoch 248/1000
# 100/100 - 0s - loss: 0.1471 - binary_accuracy: 0.9400
# Epoch 249/1000
# 100/100 - 0s - loss: 0.1491 - binary_accuracy: 0.9400
# Epoch 250/1000
# 100/100 - 0s - loss: 0.1408 - binary_accuracy: 0.9500
# Epoch 251/1000
# 100/100 - 0s - loss: 0.1837 - binary_accuracy: 0.8900
# Epoch 252/1000
# 100/100 - 0s - loss: 0.1584 - binary_accuracy: 0.9200
# Epoch 253/1000
# 100/100 - 0s - loss: 0.1525 - binary_accuracy: 0.9400
# Epoch 254/1000
# 100/100 - 0s - loss: 0.1546 - binary_accuracy: 0.9400
# Epoch 255/1000
# 100/100 - 0s - loss: 0.1485 - binary_accuracy: 0.9200
# Epoch 256/1000
# 100/100 - 0s - loss: 0.1568 - binary_accuracy: 0.9200
# Epoch 257/1000
# 100/100 - 0s - loss: 0.1532 - binary_accuracy: 0.9200
# Epoch 258/1000
# 100/100 - 0s - loss: 0.1483 - binary_accuracy: 0.9300
# Epoch 259/1000
# 100/100 - 0s - loss: 0.1454 - binary_accuracy: 0.9300
# Epoch 260/1000
# 100/100 - 0s - loss: 0.1443 - binary_accuracy: 0.9200
# Epoch 261/1000
# 100/100 - 0s - loss: 0.1390 - binary_accuracy: 0.9400
# Epoch 262/1000
# 100/100 - 0s - loss: 0.1436 - binary_accuracy: 0.9400
# Epoch 263/1000
# 100/100 - 0s - loss: 0.1444 - binary_accuracy: 0.9400
# Epoch 264/1000
# 100/100 - 0s - loss: 0.1449 - binary_accuracy: 0.9400
# Epoch 265/1000
# 100/100 - 0s - loss: 0.1433 - binary_accuracy: 0.9300
# Epoch 266/1000
# 100/100 - 0s - loss: 0.1431 - binary_accuracy: 0.9300
# Epoch 267/1000
# 100/100 - 0s - loss: 0.1404 - binary_accuracy: 0.9200
# Epoch 268/1000
# 100/100 - 0s - loss: 0.1399 - binary_accuracy: 0.9300
# Epoch 269/1000
# 100/100 - 0s - loss: 0.1415 - binary_accuracy: 0.9400
# Epoch 270/1000
# 100/100 - 0s - loss: 0.1481 - binary_accuracy: 0.9300
# Epoch 271/1000
# 100/100 - 0s - loss: 0.1416 - binary_accuracy: 0.9400
# Epoch 272/1000
# 100/100 - 0s - loss: 0.1377 - binary_accuracy: 0.9400
# Epoch 273/1000
# 100/100 - 0s - loss: 0.1418 - binary_accuracy: 0.9500
# Epoch 274/1000
# 100/100 - 0s - loss: 0.1358 - binary_accuracy: 0.9400
# Epoch 275/1000
# 100/100 - 0s - loss: 0.1489 - binary_accuracy: 0.9400
# Epoch 276/1000
# 100/100 - 0s - loss: 0.1430 - binary_accuracy: 0.9300
# Epoch 277/1000
# 100/100 - 0s - loss: 0.1503 - binary_accuracy: 0.9300
# Epoch 278/1000
# 100/100 - 0s - loss: 0.1446 - binary_accuracy: 0.9400
# Epoch 279/1000
# 100/100 - 0s - loss: 0.1394 - binary_accuracy: 0.9400
# Epoch 280/1000
# 100/100 - 0s - loss: 0.1413 - binary_accuracy: 0.9500
# Epoch 281/1000
# 100/100 - 0s - loss: 0.1577 - binary_accuracy: 0.9500
# Epoch 282/1000
# 100/100 - 0s - loss: 0.1484 - binary_accuracy: 0.9400
# Epoch 283/1000
# 100/100 - 0s - loss: 0.1360 - binary_accuracy: 0.9400
# Epoch 284/1000
# 100/100 - 0s - loss: 0.1386 - binary_accuracy: 0.9400
# Epoch 285/1000
# 100/100 - 0s - loss: 0.1346 - binary_accuracy: 0.9400
# Epoch 286/1000
# 100/100 - 0s - loss: 0.1468 - binary_accuracy: 0.9500
# Epoch 287/1000
# 100/100 - 0s - loss: 0.1428 - binary_accuracy: 0.9400
# Epoch 288/1000
# 100/100 - 0s - loss: 0.1410 - binary_accuracy: 0.9300
# Epoch 289/1000
# 100/100 - 0s - loss: 0.1459 - binary_accuracy: 0.9300
# Epoch 290/1000
# 100/100 - 0s - loss: 0.1381 - binary_accuracy: 0.9400
# Epoch 291/1000
# 100/100 - 0s - loss: 0.1356 - binary_accuracy: 0.9300
# Epoch 292/1000
# 100/100 - 0s - loss: 0.1362 - binary_accuracy: 0.9400
# Epoch 293/1000
# 100/100 - 0s - loss: 0.1439 - binary_accuracy: 0.9400
# Epoch 294/1000
# 100/100 - 0s - loss: 0.1473 - binary_accuracy: 0.9400
# Epoch 295/1000
# 100/100 - 0s - loss: 0.1410 - binary_accuracy: 0.9500
# Epoch 296/1000
# 100/100 - 0s - loss: 0.1379 - binary_accuracy: 0.9400
# Epoch 297/1000
# 100/100 - 0s - loss: 0.1380 - binary_accuracy: 0.9500
# Epoch 298/1000
# 100/100 - 0s - loss: 0.1381 - binary_accuracy: 0.9500
# Epoch 299/1000
# 100/100 - 0s - loss: 0.1368 - binary_accuracy: 0.9500
# Epoch 300/1000
# 100/100 - 0s - loss: 0.1490 - binary_accuracy: 0.9300
# Epoch 301/1000
# 100/100 - 0s - loss: 0.1798 - binary_accuracy: 0.9300
# Epoch 302/1000
# 100/100 - 0s - loss: 0.1698 - binary_accuracy: 0.9300
# Epoch 303/1000
# 100/100 - 0s - loss: 0.1626 - binary_accuracy: 0.9100
# Epoch 304/1000
# 100/100 - 0s - loss: 0.1539 - binary_accuracy: 0.9300
# Epoch 305/1000
# 100/100 - 0s - loss: 0.1438 - binary_accuracy: 0.9300
# Epoch 306/1000
# 100/100 - 0s - loss: 0.1412 - binary_accuracy: 0.9400
# Epoch 307/1000
# 100/100 - 0s - loss: 0.1340 - binary_accuracy: 0.9400
# Epoch 308/1000
# 100/100 - 0s - loss: 0.1378 - binary_accuracy: 0.9200
# Epoch 309/1000
# 100/100 - 0s - loss: 0.1421 - binary_accuracy: 0.9300
# Epoch 310/1000
# 100/100 - 0s - loss: 0.1390 - binary_accuracy: 0.9400
# Epoch 311/1000
# 100/100 - 0s - loss: 0.1483 - binary_accuracy: 0.9500
# Epoch 312/1000
# 100/100 - 0s - loss: 0.1590 - binary_accuracy: 0.9500
# Epoch 313/1000
# 100/100 - 0s - loss: 0.1598 - binary_accuracy: 0.9400
# Epoch 314/1000
# 100/100 - 0s - loss: 0.1395 - binary_accuracy: 0.9400
# Epoch 315/1000
# 100/100 - 0s - loss: 0.1612 - binary_accuracy: 0.9000
# Epoch 316/1000
# 100/100 - 0s - loss: 0.1620 - binary_accuracy: 0.9000
# Epoch 317/1000
# 100/100 - 0s - loss: 0.1364 - binary_accuracy: 0.9500
# Epoch 318/1000
# 100/100 - 0s - loss: 0.1487 - binary_accuracy: 0.9500
# Epoch 319/1000
# 100/100 - 0s - loss: 0.1518 - binary_accuracy: 0.9500
# Epoch 320/1000
# 100/100 - 0s - loss: 0.1339 - binary_accuracy: 0.9400
# Epoch 321/1000
# 100/100 - 0s - loss: 0.1390 - binary_accuracy: 0.9300
# Epoch 322/1000
# 100/100 - 0s - loss: 0.1623 - binary_accuracy: 0.9100
# Epoch 323/1000
# 100/100 - 0s - loss: 0.1263 - binary_accuracy: 0.9300
# Epoch 324/1000
# 100/100 - 0s - loss: 0.1569 - binary_accuracy: 0.9300
# Epoch 325/1000
# 100/100 - 0s - loss: 0.1719 - binary_accuracy: 0.9300
# Epoch 326/1000
# 100/100 - 0s - loss: 0.1441 - binary_accuracy: 0.9300
# Epoch 327/1000
# 100/100 - 0s - loss: 0.1359 - binary_accuracy: 0.9400
# Epoch 328/1000
# 100/100 - 0s - loss: 0.1383 - binary_accuracy: 0.9400
# Epoch 329/1000
# 100/100 - 0s - loss: 0.1350 - binary_accuracy: 0.9400
# Epoch 330/1000
# 100/100 - 0s - loss: 0.1346 - binary_accuracy: 0.9400
# Epoch 331/1000
# 100/100 - 0s - loss: 0.1368 - binary_accuracy: 0.9400
# Epoch 332/1000
# 100/100 - 0s - loss: 0.1342 - binary_accuracy: 0.9400
# Epoch 333/1000
# 100/100 - 0s - loss: 0.1300 - binary_accuracy: 0.9400
# Epoch 334/1000
# 100/100 - 0s - loss: 0.1319 - binary_accuracy: 0.9200
# Epoch 335/1000
# 100/100 - 0s - loss: 0.1292 - binary_accuracy: 0.9300
# Epoch 336/1000
# 100/100 - 0s - loss: 0.1284 - binary_accuracy: 0.9400
# Epoch 337/1000
# 100/100 - 0s - loss: 0.1405 - binary_accuracy: 0.9400
# Epoch 338/1000
# 100/100 - 0s - loss: 0.1500 - binary_accuracy: 0.9400
# Epoch 339/1000
# 100/100 - 0s - loss: 0.1394 - binary_accuracy: 0.9500
# Epoch 340/1000
# 100/100 - 0s - loss: 0.1440 - binary_accuracy: 0.9400
# Epoch 341/1000
# 100/100 - 0s - loss: 0.1321 - binary_accuracy: 0.9500
# Epoch 342/1000
# 100/100 - 0s - loss: 0.1315 - binary_accuracy: 0.9400
# Epoch 343/1000
# 100/100 - 0s - loss: 0.1289 - binary_accuracy: 0.9400
# Epoch 344/1000
# 100/100 - 0s - loss: 0.1313 - binary_accuracy: 0.9300
# Epoch 345/1000
# 100/100 - 0s - loss: 0.1373 - binary_accuracy: 0.9300
# Epoch 346/1000
# 100/100 - 0s - loss: 0.1354 - binary_accuracy: 0.9200
# Epoch 347/1000
# 100/100 - 0s - loss: 0.1291 - binary_accuracy: 0.9400
# Epoch 348/1000
# 100/100 - 0s - loss: 0.1335 - binary_accuracy: 0.9400
# Epoch 349/1000
# 100/100 - 0s - loss: 0.1285 - binary_accuracy: 0.9400
# Epoch 350/1000
# 100/100 - 0s - loss: 0.1285 - binary_accuracy: 0.9300
# Epoch 351/1000
# 100/100 - 0s - loss: 0.1347 - binary_accuracy: 0.9400
# Epoch 352/1000
# 100/100 - 0s - loss: 0.1396 - binary_accuracy: 0.9500
# Epoch 353/1000
# 100/100 - 0s - loss: 0.1439 - binary_accuracy: 0.9400
# Epoch 354/1000
# 100/100 - 0s - loss: 0.1420 - binary_accuracy: 0.9400
# Epoch 355/1000
# 100/100 - 0s - loss: 0.1310 - binary_accuracy: 0.9600
# Epoch 356/1000
# 100/100 - 0s - loss: 0.1322 - binary_accuracy: 0.9500
# Epoch 357/1000
# 100/100 - 0s - loss: 0.1295 - binary_accuracy: 0.9500
# Epoch 358/1000
# 100/100 - 0s - loss: 0.1280 - binary_accuracy: 0.9400
# Epoch 359/1000
# 100/100 - 0s - loss: 0.1260 - binary_accuracy: 0.9400
# Epoch 360/1000
# 100/100 - 0s - loss: 0.1274 - binary_accuracy: 0.9400
# Epoch 361/1000
# 100/100 - 0s - loss: 0.1278 - binary_accuracy: 0.9400
# Epoch 362/1000
# 100/100 - 0s - loss: 0.1262 - binary_accuracy: 0.9400
# Epoch 363/1000
# 100/100 - 0s - loss: 0.1299 - binary_accuracy: 0.9400
# Epoch 364/1000
# 100/100 - 0s - loss: 0.1356 - binary_accuracy: 0.9300
# Epoch 365/1000
# 100/100 - 0s - loss: 0.1320 - binary_accuracy: 0.9200
# Epoch 366/1000
# 100/100 - 0s - loss: 0.1271 - binary_accuracy: 0.9400
# Epoch 367/1000
# 100/100 - 0s - loss: 0.1256 - binary_accuracy: 0.9400
# Epoch 368/1000
# 100/100 - 0s - loss: 0.1245 - binary_accuracy: 0.9400
# Epoch 369/1000
# 100/100 - 0s - loss: 0.1255 - binary_accuracy: 0.9400
# Epoch 370/1000
# 100/100 - 0s - loss: 0.1300 - binary_accuracy: 0.9400
# Epoch 371/1000
# 100/100 - 0s - loss: 0.1398 - binary_accuracy: 0.9400
# Epoch 372/1000
# 100/100 - 0s - loss: 0.1370 - binary_accuracy: 0.9500
# Epoch 373/1000
# 100/100 - 0s - loss: 0.1261 - binary_accuracy: 0.9500
# Epoch 374/1000
# 100/100 - 0s - loss: 0.1410 - binary_accuracy: 0.9300
# Epoch 375/1000
# 100/100 - 0s - loss: 0.1508 - binary_accuracy: 0.9300
# Epoch 376/1000
# 100/100 - 0s - loss: 0.1424 - binary_accuracy: 0.9300
# Epoch 377/1000
# 100/100 - 0s - loss: 0.1270 - binary_accuracy: 0.9400
# Epoch 378/1000
# 100/100 - 0s - loss: 0.1277 - binary_accuracy: 0.9500
# Epoch 379/1000
# 100/100 - 0s - loss: 0.1281 - binary_accuracy: 0.9500
# Epoch 380/1000
# 100/100 - 0s - loss: 0.1253 - binary_accuracy: 0.9400
# Epoch 381/1000
# 100/100 - 0s - loss: 0.1313 - binary_accuracy: 0.9200
# Epoch 382/1000
# 100/100 - 0s - loss: 0.1274 - binary_accuracy: 0.9300
# Epoch 383/1000
# 100/100 - 0s - loss: 0.1247 - binary_accuracy: 0.9400
# Epoch 384/1000
# 100/100 - 0s - loss: 0.1281 - binary_accuracy: 0.9400
# Epoch 385/1000
# 100/100 - 0s - loss: 0.1320 - binary_accuracy: 0.9400
# Epoch 386/1000
# 100/100 - 0s - loss: 0.1295 - binary_accuracy: 0.9400
# Epoch 387/1000
# 100/100 - 0s - loss: 0.1259 - binary_accuracy: 0.9400
# Epoch 388/1000
# 100/100 - 0s - loss: 0.1250 - binary_accuracy: 0.9400
# Epoch 389/1000
# 100/100 - 0s - loss: 0.1347 - binary_accuracy: 0.9300
# Epoch 390/1000
# 100/100 - 0s - loss: 0.1291 - binary_accuracy: 0.9400
# Epoch 391/1000
# 100/100 - 0s - loss: 0.1238 - binary_accuracy: 0.9300
# Epoch 392/1000
# 100/100 - 0s - loss: 0.1250 - binary_accuracy: 0.9400
# Epoch 393/1000
# 100/100 - 0s - loss: 0.1290 - binary_accuracy: 0.9400
# Epoch 394/1000
# 100/100 - 0s - loss: 0.1285 - binary_accuracy: 0.9500
# Epoch 395/1000
# 100/100 - 0s - loss: 0.1245 - binary_accuracy: 0.9500
# Epoch 396/1000
# 100/100 - 0s - loss: 0.1232 - binary_accuracy: 0.9400
# Epoch 397/1000
# 100/100 - 0s - loss: 0.1232 - binary_accuracy: 0.9400
# Epoch 398/1000
# 100/100 - 0s - loss: 0.1217 - binary_accuracy: 0.9400
# Epoch 399/1000
# 100/100 - 0s - loss: 0.1222 - binary_accuracy: 0.9400
# Epoch 400/1000
# 100/100 - 0s - loss: 0.1279 - binary_accuracy: 0.9300
# Epoch 401/1000
# 100/100 - 0s - loss: 0.1332 - binary_accuracy: 0.9500
# Epoch 402/1000
# 100/100 - 0s - loss: 0.1242 - binary_accuracy: 0.9400
# Epoch 403/1000
# 100/100 - 0s - loss: 0.1233 - binary_accuracy: 0.9400
# Epoch 404/1000
# 100/100 - 0s - loss: 0.1216 - binary_accuracy: 0.9300
# Epoch 405/1000
# 100/100 - 0s - loss: 0.1171 - binary_accuracy: 0.9400
# Epoch 406/1000
# 100/100 - 0s - loss: 0.1367 - binary_accuracy: 0.9500
# Epoch 407/1000
# 100/100 - 0s - loss: 0.1307 - binary_accuracy: 0.9600
# Epoch 408/1000
# 100/100 - 0s - loss: 0.1256 - binary_accuracy: 0.9400
# Epoch 409/1000
# 100/100 - 0s - loss: 0.1333 - binary_accuracy: 0.9300
# Epoch 410/1000
# 100/100 - 0s - loss: 0.1299 - binary_accuracy: 0.9400
# Epoch 411/1000
# 100/100 - 0s - loss: 0.1255 - binary_accuracy: 0.9400
# Epoch 412/1000
# 100/100 - 0s - loss: 0.1205 - binary_accuracy: 0.9300
# Epoch 413/1000
# 100/100 - 0s - loss: 0.1240 - binary_accuracy: 0.9300
# Epoch 414/1000
# 100/100 - 0s - loss: 0.1178 - binary_accuracy: 0.9400
# Epoch 415/1000
# 100/100 - 0s - loss: 0.1324 - binary_accuracy: 0.9300
# Epoch 416/1000
# 100/100 - 0s - loss: 0.1394 - binary_accuracy: 0.9400
# Epoch 417/1000
# 100/100 - 0s - loss: 0.1273 - binary_accuracy: 0.9500
# Epoch 418/1000
# 100/100 - 0s - loss: 0.1178 - binary_accuracy: 0.9400
# Epoch 419/1000
# 100/100 - 0s - loss: 0.1303 - binary_accuracy: 0.9400
# Epoch 420/1000
# 100/100 - 0s - loss: 0.1376 - binary_accuracy: 0.9400
# Epoch 421/1000
# 100/100 - 0s - loss: 0.1293 - binary_accuracy: 0.9400
# Epoch 422/1000
# 100/100 - 0s - loss: 0.1442 - binary_accuracy: 0.9400
# Epoch 423/1000
# 100/100 - 0s - loss: 0.1398 - binary_accuracy: 0.9300
# Epoch 424/1000
# 100/100 - 0s - loss: 0.1185 - binary_accuracy: 0.9400
# Epoch 425/1000
# 100/100 - 0s - loss: 0.1294 - binary_accuracy: 0.9300
# Epoch 426/1000
# 100/100 - 0s - loss: 0.1347 - binary_accuracy: 0.9300
# Epoch 427/1000
# 100/100 - 0s - loss: 0.1299 - binary_accuracy: 0.9400
# Epoch 428/1000
# 100/100 - 0s - loss: 0.1239 - binary_accuracy: 0.9600
# Epoch 429/1000
# 100/100 - 0s - loss: 0.1202 - binary_accuracy: 0.9500
# Epoch 430/1000
# 100/100 - 0s - loss: 0.1175 - binary_accuracy: 0.9400
# Epoch 431/1000
# 100/100 - 0s - loss: 0.1179 - binary_accuracy: 0.9400
# Epoch 432/1000
# 100/100 - 0s - loss: 0.1169 - binary_accuracy: 0.9400
# Epoch 433/1000
# 100/100 - 0s - loss: 0.1179 - binary_accuracy: 0.9400
# Epoch 434/1000
# 100/100 - 0s - loss: 0.1178 - binary_accuracy: 0.9400
# Epoch 435/1000
# 100/100 - 0s - loss: 0.1177 - binary_accuracy: 0.9400
# Epoch 436/1000
# 100/100 - 0s - loss: 0.1177 - binary_accuracy: 0.9400
# Epoch 437/1000
# 100/100 - 0s - loss: 0.1179 - binary_accuracy: 0.9400
# Epoch 438/1000
# 100/100 - 0s - loss: 0.1175 - binary_accuracy: 0.9400
# Epoch 439/1000
# 100/100 - 0s - loss: 0.1228 - binary_accuracy: 0.9200
# Epoch 440/1000
# 100/100 - 0s - loss: 0.1235 - binary_accuracy: 0.9300
# Epoch 441/1000
# 100/100 - 0s - loss: 0.1213 - binary_accuracy: 0.9300
# Epoch 442/1000
# 100/100 - 0s - loss: 0.1185 - binary_accuracy: 0.9400
# Epoch 443/1000
# 100/100 - 0s - loss: 0.1223 - binary_accuracy: 0.9500
# Epoch 444/1000
# 100/100 - 0s - loss: 0.1267 - binary_accuracy: 0.9300
# Epoch 445/1000
# 100/100 - 0s - loss: 0.1244 - binary_accuracy: 0.9700
# Epoch 446/1000
# 100/100 - 0s - loss: 0.1275 - binary_accuracy: 0.9600
# Epoch 447/1000
# 100/100 - 0s - loss: 0.1146 - binary_accuracy: 0.9600
# Epoch 448/1000
# 100/100 - 0s - loss: 0.1335 - binary_accuracy: 0.9400
# Epoch 449/1000
# 100/100 - 0s - loss: 0.1393 - binary_accuracy: 0.9400
# Epoch 450/1000
# 100/100 - 0s - loss: 0.1297 - binary_accuracy: 0.9400
# Epoch 451/1000
# 100/100 - 0s - loss: 0.1201 - binary_accuracy: 0.9400
# Epoch 452/1000
# 100/100 - 0s - loss: 0.1156 - binary_accuracy: 0.9400
# Epoch 453/1000
# 100/100 - 0s - loss: 0.1239 - binary_accuracy: 0.9500
# Epoch 454/1000
# 100/100 - 0s - loss: 0.1188 - binary_accuracy: 0.9400
# Epoch 455/1000
# 100/100 - 0s - loss: 0.1346 - binary_accuracy: 0.9400
# Epoch 456/1000
# 100/100 - 0s - loss: 0.1469 - binary_accuracy: 0.9400
# Epoch 457/1000
# 100/100 - 0s - loss: 0.1374 - binary_accuracy: 0.9500
# Epoch 458/1000
# 100/100 - 0s - loss: 0.1241 - binary_accuracy: 0.9300
# Epoch 459/1000
# 100/100 - 0s - loss: 0.1217 - binary_accuracy: 0.9400
# Epoch 460/1000
# 100/100 - 0s - loss: 0.1264 - binary_accuracy: 0.9400
# Epoch 461/1000
# 100/100 - 0s - loss: 0.1126 - binary_accuracy: 0.9400
# Epoch 462/1000
# 100/100 - 0s - loss: 0.1218 - binary_accuracy: 0.9400
# Epoch 463/1000
# 100/100 - 0s - loss: 0.1241 - binary_accuracy: 0.9400
# Epoch 464/1000
# 100/100 - 0s - loss: 0.1173 - binary_accuracy: 0.9400
# Epoch 465/1000
# 100/100 - 0s - loss: 0.1152 - binary_accuracy: 0.9300
# Epoch 466/1000
# 100/100 - 0s - loss: 0.1147 - binary_accuracy: 0.9400
# Epoch 467/1000
# 100/100 - 0s - loss: 0.1156 - binary_accuracy: 0.9500
# Epoch 468/1000
# 100/100 - 0s - loss: 0.1218 - binary_accuracy: 0.9500
# Epoch 469/1000
# 100/100 - 0s - loss: 0.1235 - binary_accuracy: 0.9500
# Epoch 470/1000
# 100/100 - 0s - loss: 0.1152 - binary_accuracy: 0.9400
# Epoch 471/1000
# 100/100 - 0s - loss: 0.1182 - binary_accuracy: 0.9300
# Epoch 472/1000
# 100/100 - 0s - loss: 0.1238 - binary_accuracy: 0.9300
# Epoch 473/1000
# 100/100 - 0s - loss: 0.1213 - binary_accuracy: 0.9400
# Epoch 474/1000
# 100/100 - 0s - loss: 0.1186 - binary_accuracy: 0.9400
# Epoch 475/1000
# 100/100 - 0s - loss: 0.1147 - binary_accuracy: 0.9400
# Epoch 476/1000
# 100/100 - 0s - loss: 0.1202 - binary_accuracy: 0.9400
# Epoch 477/1000
# 100/100 - 0s - loss: 0.1120 - binary_accuracy: 0.9300
# Epoch 478/1000
# 100/100 - 0s - loss: 0.1104 - binary_accuracy: 0.9400
# Epoch 479/1000
# 100/100 - 0s - loss: 0.1141 - binary_accuracy: 0.9500
# Epoch 480/1000
# 100/100 - 0s - loss: 0.1151 - binary_accuracy: 0.9500
# Epoch 481/1000
# 100/100 - 0s - loss: 0.1115 - binary_accuracy: 0.9500
# Epoch 482/1000
# 100/100 - 0s - loss: 0.1105 - binary_accuracy: 0.9400
# Epoch 483/1000
# 100/100 - 0s - loss: 0.1111 - binary_accuracy: 0.9500
# Epoch 484/1000
# 100/100 - 0s - loss: 0.1192 - binary_accuracy: 0.9500
# Epoch 485/1000
# 100/100 - 0s - loss: 0.1198 - binary_accuracy: 0.9400
# Epoch 486/1000
# 100/100 - 0s - loss: 0.1096 - binary_accuracy: 0.9500
# Epoch 487/1000
# 100/100 - 0s - loss: 0.1141 - binary_accuracy: 0.9400
# Epoch 488/1000
# 100/100 - 0s - loss: 0.1173 - binary_accuracy: 0.9400
# Epoch 489/1000
# 100/100 - 0s - loss: 0.1135 - binary_accuracy: 0.9400
# Epoch 490/1000
# 100/100 - 0s - loss: 0.1094 - binary_accuracy: 0.9400
# Epoch 491/1000
# 100/100 - 0s - loss: 0.1116 - binary_accuracy: 0.9400
# Epoch 492/1000
# 100/100 - 0s - loss: 0.1171 - binary_accuracy: 0.9500
# Epoch 493/1000
# 100/100 - 0s - loss: 0.1232 - binary_accuracy: 0.9400
# Epoch 494/1000
# 100/100 - 0s - loss: 0.1213 - binary_accuracy: 0.9400
# Epoch 495/1000
# 100/100 - 0s - loss: 0.1122 - binary_accuracy: 0.9500
# Epoch 496/1000
# 100/100 - 0s - loss: 0.1113 - binary_accuracy: 0.9400
# Epoch 497/1000
# 100/100 - 0s - loss: 0.1113 - binary_accuracy: 0.9500
# Epoch 498/1000
# 100/100 - 0s - loss: 0.1091 - binary_accuracy: 0.9500
# Epoch 499/1000
# 100/100 - 0s - loss: 0.1084 - binary_accuracy: 0.9500
# Epoch 500/1000
# 100/100 - 0s - loss: 0.1094 - binary_accuracy: 0.9500
# Epoch 501/1000
# 100/100 - 0s - loss: 0.1084 - binary_accuracy: 0.9400
# Epoch 502/1000
# 100/100 - 0s - loss: 0.1164 - binary_accuracy: 0.9400
# Epoch 503/1000
# 100/100 - 0s - loss: 0.1144 - binary_accuracy: 0.9400
# Epoch 504/1000
# 100/100 - 0s - loss: 0.1103 - binary_accuracy: 0.9400
# Epoch 505/1000
# 100/100 - 0s - loss: 0.1135 - binary_accuracy: 0.9400
# Epoch 506/1000
# 100/100 - 0s - loss: 0.1124 - binary_accuracy: 0.9400
# Epoch 507/1000
# 100/100 - 0s - loss: 0.1065 - binary_accuracy: 0.9400
# Epoch 508/1000
# 100/100 - 0s - loss: 0.1091 - binary_accuracy: 0.9400
# Epoch 509/1000
# 100/100 - 0s - loss: 0.1053 - binary_accuracy: 0.9400
# Epoch 510/1000
# 100/100 - 0s - loss: 0.1078 - binary_accuracy: 0.9500
# Epoch 511/1000
# 100/100 - 0s - loss: 0.1075 - binary_accuracy: 0.9400
# Epoch 512/1000
# 100/100 - 0s - loss: 0.1180 - binary_accuracy: 0.9400
# Epoch 513/1000
# 100/100 - 0s - loss: 0.1208 - binary_accuracy: 0.9300
# Epoch 514/1000
# 100/100 - 0s - loss: 0.1110 - binary_accuracy: 0.9500
# Epoch 515/1000
# 100/100 - 0s - loss: 0.1069 - binary_accuracy: 0.9600
# Epoch 516/1000
# 100/100 - 0s - loss: 0.1061 - binary_accuracy: 0.9500
# Epoch 517/1000
# 100/100 - 0s - loss: 0.1068 - binary_accuracy: 0.9500
# Epoch 518/1000
# 100/100 - 0s - loss: 0.1071 - binary_accuracy: 0.9400
# Epoch 519/1000
# 100/100 - 0s - loss: 0.1084 - binary_accuracy: 0.9400
# Epoch 520/1000
# 100/100 - 0s - loss: 0.1106 - binary_accuracy: 0.9400
# Epoch 521/1000
# 100/100 - 0s - loss: 0.1111 - binary_accuracy: 0.9400
# Epoch 522/1000
# 100/100 - 0s - loss: 0.1054 - binary_accuracy: 0.9400
# Epoch 523/1000
# 100/100 - 0s - loss: 0.1050 - binary_accuracy: 0.9400
# Epoch 524/1000
# 100/100 - 0s - loss: 0.1055 - binary_accuracy: 0.9400
# Epoch 525/1000
# 100/100 - 0s - loss: 0.1037 - binary_accuracy: 0.9400
# Epoch 526/1000
# 100/100 - 0s - loss: 0.1037 - binary_accuracy: 0.9400
# Epoch 527/1000
# 100/100 - 0s - loss: 0.1055 - binary_accuracy: 0.9400
# Epoch 528/1000
# 100/100 - 0s - loss: 0.1081 - binary_accuracy: 0.9400
# Epoch 529/1000
# 100/100 - 0s - loss: 0.1091 - binary_accuracy: 0.9500
# Epoch 530/1000
# 100/100 - 0s - loss: 0.1059 - binary_accuracy: 0.9500
# Epoch 531/1000
# 100/100 - 0s - loss: 0.1039 - binary_accuracy: 0.9500
# Epoch 532/1000
# 100/100 - 0s - loss: 0.1236 - binary_accuracy: 0.9400
# Epoch 533/1000
# 100/100 - 0s - loss: 0.1345 - binary_accuracy: 0.9400
# Epoch 534/1000
# 100/100 - 0s - loss: 0.1124 - binary_accuracy: 0.9600
# Epoch 535/1000
# 100/100 - 0s - loss: 0.1147 - binary_accuracy: 0.9400
# Epoch 536/1000
# 100/100 - 0s - loss: 0.1114 - binary_accuracy: 0.9500
# Epoch 537/1000
# 100/100 - 0s - loss: 0.1118 - binary_accuracy: 0.9400
# Epoch 538/1000
# 100/100 - 0s - loss: 0.1122 - binary_accuracy: 0.9500
# Epoch 539/1000
# 100/100 - 0s - loss: 0.1084 - binary_accuracy: 0.9400
# Epoch 540/1000
# 100/100 - 0s - loss: 0.1161 - binary_accuracy: 0.9400
# Epoch 541/1000
# 100/100 - 0s - loss: 0.1156 - binary_accuracy: 0.9400
# Epoch 542/1000
# 100/100 - 0s - loss: 0.1047 - binary_accuracy: 0.9500
# Epoch 543/1000
# 100/100 - 0s - loss: 0.1031 - binary_accuracy: 0.9400
# Epoch 544/1000
# 100/100 - 0s - loss: 0.1014 - binary_accuracy: 0.9500
# Epoch 545/1000
# 100/100 - 0s - loss: 0.1023 - binary_accuracy: 0.9400
# Epoch 546/1000
# 100/100 - 0s - loss: 0.1013 - binary_accuracy: 0.9400
# Epoch 547/1000
# 100/100 - 0s - loss: 0.1025 - binary_accuracy: 0.9400
# Epoch 548/1000
# 100/100 - 0s - loss: 0.1027 - binary_accuracy: 0.9400
# Epoch 549/1000
# 100/100 - 0s - loss: 0.1010 - binary_accuracy: 0.9400
# Epoch 550/1000
# 100/100 - 0s - loss: 0.0996 - binary_accuracy: 0.9400
# Epoch 551/1000
# 100/100 - 0s - loss: 0.0985 - binary_accuracy: 0.9500
# Epoch 552/1000
# 100/100 - 0s - loss: 0.0988 - binary_accuracy: 0.9500
# Epoch 553/1000
# 100/100 - 0s - loss: 0.0982 - binary_accuracy: 0.9500
# Epoch 554/1000
# 100/100 - 0s - loss: 0.1004 - binary_accuracy: 0.9500
# Epoch 555/1000
# 100/100 - 0s - loss: 0.1003 - binary_accuracy: 0.9400
# Epoch 556/1000
# 100/100 - 0s - loss: 0.1005 - binary_accuracy: 0.9500
# Epoch 557/1000
# 100/100 - 0s - loss: 0.1041 - binary_accuracy: 0.9400
# Epoch 558/1000
# 100/100 - 0s - loss: 0.1023 - binary_accuracy: 0.9400
# Epoch 559/1000
# 100/100 - 0s - loss: 0.1010 - binary_accuracy: 0.9400
# Epoch 560/1000
# 100/100 - 0s - loss: 0.0985 - binary_accuracy: 0.9400
# Epoch 561/1000
# 100/100 - 0s - loss: 0.0977 - binary_accuracy: 0.9500
# Epoch 562/1000
# 100/100 - 0s - loss: 0.0969 - binary_accuracy: 0.9600
# Epoch 563/1000
# 100/100 - 0s - loss: 0.1031 - binary_accuracy: 0.9500
# Epoch 564/1000
# 100/100 - 0s - loss: 0.1011 - binary_accuracy: 0.9600
# Epoch 565/1000
# 100/100 - 0s - loss: 0.0975 - binary_accuracy: 0.9400
# Epoch 566/1000
# 100/100 - 0s - loss: 0.0957 - binary_accuracy: 0.9500
# Epoch 567/1000
# 100/100 - 0s - loss: 0.1009 - binary_accuracy: 0.9500
# Epoch 568/1000
# 100/100 - 0s - loss: 0.1004 - binary_accuracy: 0.9500
# Epoch 569/1000
# 100/100 - 0s - loss: 0.0957 - binary_accuracy: 0.9500
# Epoch 570/1000
# 100/100 - 0s - loss: 0.0962 - binary_accuracy: 0.9400
# Epoch 571/1000
# 100/100 - 0s - loss: 0.0981 - binary_accuracy: 0.9500
# Epoch 572/1000
# 100/100 - 0s - loss: 0.0962 - binary_accuracy: 0.9500
# Epoch 573/1000
# 100/100 - 0s - loss: 0.0960 - binary_accuracy: 0.9500
# Epoch 574/1000
# 100/100 - 0s - loss: 0.0994 - binary_accuracy: 0.9500
# Epoch 575/1000
# 100/100 - 0s - loss: 0.0966 - binary_accuracy: 0.9500
# Epoch 576/1000
# 100/100 - 0s - loss: 0.0958 - binary_accuracy: 0.9500
# Epoch 577/1000
# 100/100 - 0s - loss: 0.0946 - binary_accuracy: 0.9500
# Epoch 578/1000
# 100/100 - 0s - loss: 0.0940 - binary_accuracy: 0.9500
# Epoch 579/1000
# 100/100 - 0s - loss: 0.0994 - binary_accuracy: 0.9600
# Epoch 580/1000
# 100/100 - 0s - loss: 0.0990 - binary_accuracy: 0.9600
# Epoch 581/1000
# 100/100 - 0s - loss: 0.0981 - binary_accuracy: 0.9600
# Epoch 582/1000
# 100/100 - 0s - loss: 0.0945 - binary_accuracy: 0.9500
# Epoch 583/1000
# 100/100 - 0s - loss: 0.0954 - binary_accuracy: 0.9500
# Epoch 584/1000
# 100/100 - 0s - loss: 0.0922 - binary_accuracy: 0.9400
# Epoch 585/1000
# 100/100 - 0s - loss: 0.0972 - binary_accuracy: 0.9500
# Epoch 586/1000
# 100/100 - 0s - loss: 0.1011 - binary_accuracy: 0.9400
# Epoch 587/1000
# 100/100 - 0s - loss: 0.0964 - binary_accuracy: 0.9500
# Epoch 588/1000
# 100/100 - 0s - loss: 0.0981 - binary_accuracy: 0.9500
# Epoch 589/1000
# 100/100 - 0s - loss: 0.1093 - binary_accuracy: 0.9400
# Epoch 590/1000
# 100/100 - 0s - loss: 0.1104 - binary_accuracy: 0.9500
# Epoch 591/1000
# 100/100 - 0s - loss: 0.1129 - binary_accuracy: 0.9500
# Epoch 592/1000
# 100/100 - 0s - loss: 0.1064 - binary_accuracy: 0.9700
# Epoch 593/1000
# 100/100 - 0s - loss: 0.1038 - binary_accuracy: 0.9600
# Epoch 594/1000
# 100/100 - 0s - loss: 0.0997 - binary_accuracy: 0.9500
# Epoch 595/1000
# 100/100 - 0s - loss: 0.0952 - binary_accuracy: 0.9500
# Epoch 596/1000
# 100/100 - 0s - loss: 0.0957 - binary_accuracy: 0.9500
# Epoch 597/1000
# 100/100 - 0s - loss: 0.0961 - binary_accuracy: 0.9500
# Epoch 598/1000
# 100/100 - 0s - loss: 0.0941 - binary_accuracy: 0.9500
# Epoch 599/1000
# 100/100 - 0s - loss: 0.0923 - binary_accuracy: 0.9500
# Epoch 600/1000
# 100/100 - 0s - loss: 0.0953 - binary_accuracy: 0.9500
# Epoch 601/1000
# 100/100 - 0s - loss: 0.0928 - binary_accuracy: 0.9500
# Epoch 602/1000
# 100/100 - 0s - loss: 0.0973 - binary_accuracy: 0.9600
# Epoch 603/1000
# 100/100 - 0s - loss: 0.1003 - binary_accuracy: 0.9500
# Epoch 604/1000
# 100/100 - 0s - loss: 0.0937 - binary_accuracy: 0.9600
# Epoch 605/1000
# 100/100 - 0s - loss: 0.0975 - binary_accuracy: 0.9500
# Epoch 606/1000
# 100/100 - 0s - loss: 0.0951 - binary_accuracy: 0.9500
# Epoch 607/1000
# 100/100 - 0s - loss: 0.0908 - binary_accuracy: 0.9600
# Epoch 608/1000
# 100/100 - 0s - loss: 0.0915 - binary_accuracy: 0.9400
# Epoch 609/1000
# 100/100 - 0s - loss: 0.0875 - binary_accuracy: 0.9500
# Epoch 610/1000
# 100/100 - 0s - loss: 0.0940 - binary_accuracy: 0.9600
# Epoch 611/1000
# 100/100 - 0s - loss: 0.0948 - binary_accuracy: 0.9600
# Epoch 612/1000
# 100/100 - 0s - loss: 0.0968 - binary_accuracy: 0.9500
# Epoch 613/1000
# 100/100 - 0s - loss: 0.0991 - binary_accuracy: 0.9500
# Epoch 614/1000
# 100/100 - 0s - loss: 0.0931 - binary_accuracy: 0.9400
# Epoch 615/1000
# 100/100 - 0s - loss: 0.0941 - binary_accuracy: 0.9500
# Epoch 616/1000
# 100/100 - 0s - loss: 0.0905 - binary_accuracy: 0.9600
# Epoch 617/1000
# 100/100 - 0s - loss: 0.0923 - binary_accuracy: 0.9600
# Epoch 618/1000
# 100/100 - 0s - loss: 0.0906 - binary_accuracy: 0.9700
# Epoch 619/1000
# 100/100 - 0s - loss: 0.0984 - binary_accuracy: 0.9500
# Epoch 620/1000
# 100/100 - 0s - loss: 0.0974 - binary_accuracy: 0.9500
# Epoch 621/1000
# 100/100 - 0s - loss: 0.0921 - binary_accuracy: 0.9500
# Epoch 622/1000
# 100/100 - 0s - loss: 0.0933 - binary_accuracy: 0.9500
# Epoch 623/1000
# 100/100 - 0s - loss: 0.0940 - binary_accuracy: 0.9600
# Epoch 624/1000
# 100/100 - 0s - loss: 0.0924 - binary_accuracy: 0.9600
# Epoch 625/1000
# 100/100 - 0s - loss: 0.0926 - binary_accuracy: 0.9600
# Epoch 626/1000
# 100/100 - 0s - loss: 0.0900 - binary_accuracy: 0.9500
# Epoch 627/1000
# 100/100 - 0s - loss: 0.0891 - binary_accuracy: 0.9500
# Epoch 628/1000
# 100/100 - 0s - loss: 0.0897 - binary_accuracy: 0.9500
# Epoch 629/1000
# 100/100 - 0s - loss: 0.0910 - binary_accuracy: 0.9500
# Epoch 630/1000
# 100/100 - 0s - loss: 0.0935 - binary_accuracy: 0.9500
# Epoch 631/1000
# 100/100 - 0s - loss: 0.0923 - binary_accuracy: 0.9500
# Epoch 632/1000
# 100/100 - 0s - loss: 0.0884 - binary_accuracy: 0.9500
# Epoch 633/1000
# 100/100 - 0s - loss: 0.0895 - binary_accuracy: 0.9500
# Epoch 634/1000
# 100/100 - 0s - loss: 0.0881 - binary_accuracy: 0.9600
# Epoch 635/1000
# 100/100 - 0s - loss: 0.0867 - binary_accuracy: 0.9500
# Epoch 636/1000
# 100/100 - 0s - loss: 0.0880 - binary_accuracy: 0.9600
# Epoch 637/1000
# 100/100 - 0s - loss: 0.0903 - binary_accuracy: 0.9600
# Epoch 638/1000
# 100/100 - 0s - loss: 0.0895 - binary_accuracy: 0.9600
# Epoch 639/1000
# 100/100 - 0s - loss: 0.0898 - binary_accuracy: 0.9500
# Epoch 640/1000
# 100/100 - 0s - loss: 0.0938 - binary_accuracy: 0.9500
# Epoch 641/1000
# 100/100 - 0s - loss: 0.0914 - binary_accuracy: 0.9700
# Epoch 642/1000
# 100/100 - 0s - loss: 0.0884 - binary_accuracy: 0.9700
# Epoch 643/1000
# 100/100 - 0s - loss: 0.0877 - binary_accuracy: 0.9700
# Epoch 644/1000
# 100/100 - 0s - loss: 0.0902 - binary_accuracy: 0.9700
# Epoch 645/1000
# 100/100 - 0s - loss: 0.0882 - binary_accuracy: 0.9500
# Epoch 646/1000
# 100/100 - 0s - loss: 0.0893 - binary_accuracy: 0.9500
# Epoch 647/1000
# 100/100 - 0s - loss: 0.0837 - binary_accuracy: 0.9500
# Epoch 648/1000
# 100/100 - 0s - loss: 0.0863 - binary_accuracy: 0.9500
# Epoch 649/1000
# 100/100 - 0s - loss: 0.0874 - binary_accuracy: 0.9600
# Epoch 650/1000
# 100/100 - 0s - loss: 0.0862 - binary_accuracy: 0.9600
# Epoch 651/1000
# 100/100 - 0s - loss: 0.0839 - binary_accuracy: 0.9600
# Epoch 652/1000
# 100/100 - 0s - loss: 0.0841 - binary_accuracy: 0.9600
# Epoch 653/1000
# 100/100 - 0s - loss: 0.0851 - binary_accuracy: 0.9500
# Epoch 654/1000
# 100/100 - 0s - loss: 0.0873 - binary_accuracy: 0.9500
# Epoch 655/1000
# 100/100 - 0s - loss: 0.0903 - binary_accuracy: 0.9700
# Epoch 656/1000
# 100/100 - 0s - loss: 0.1006 - binary_accuracy: 0.9600
# Epoch 657/1000
# 100/100 - 0s - loss: 0.0958 - binary_accuracy: 0.9600
# Epoch 658/1000
# 100/100 - 0s - loss: 0.0979 - binary_accuracy: 0.9400
# Epoch 659/1000
# 100/100 - 0s - loss: 0.0998 - binary_accuracy: 0.9400
# Epoch 660/1000
# 100/100 - 0s - loss: 0.1004 - binary_accuracy: 0.9500
# Epoch 661/1000
# 100/100 - 0s - loss: 0.0958 - binary_accuracy: 0.9700
# Epoch 662/1000
# 100/100 - 0s - loss: 0.0860 - binary_accuracy: 0.9700
# Epoch 663/1000
# 100/100 - 0s - loss: 0.0928 - binary_accuracy: 0.9500
# Epoch 664/1000
# 100/100 - 0s - loss: 0.0911 - binary_accuracy: 0.9500
# Epoch 665/1000
# 100/100 - 0s - loss: 0.0858 - binary_accuracy: 0.9600
# Epoch 666/1000
# 100/100 - 0s - loss: 0.0862 - binary_accuracy: 0.9700
# Epoch 667/1000
# 100/100 - 0s - loss: 0.0851 - binary_accuracy: 0.9700
# Epoch 668/1000
# 100/100 - 0s - loss: 0.0848 - binary_accuracy: 0.9600
# Epoch 669/1000
# 100/100 - 0s - loss: 0.0867 - binary_accuracy: 0.9500
# Epoch 670/1000
# 100/100 - 0s - loss: 0.0904 - binary_accuracy: 0.9500
# Epoch 671/1000
# 100/100 - 0s - loss: 0.0949 - binary_accuracy: 0.9500
# Epoch 672/1000
# 100/100 - 0s - loss: 0.1075 - binary_accuracy: 0.9700
# Epoch 673/1000
# 100/100 - 0s - loss: 0.1162 - binary_accuracy: 0.9600
# Epoch 674/1000
# 100/100 - 0s - loss: 0.0921 - binary_accuracy: 0.9600
# Epoch 675/1000
# 100/100 - 0s - loss: 0.0924 - binary_accuracy: 0.9500
# Epoch 676/1000
# 100/100 - 0s - loss: 0.0911 - binary_accuracy: 0.9700
# Epoch 677/1000
# 100/100 - 0s - loss: 0.0892 - binary_accuracy: 0.9600
# Epoch 678/1000
# 100/100 - 0s - loss: 0.0856 - binary_accuracy: 0.9700
# Epoch 679/1000
# 100/100 - 0s - loss: 0.0832 - binary_accuracy: 0.9600
# Epoch 680/1000
# 100/100 - 0s - loss: 0.0845 - binary_accuracy: 0.9600
# Epoch 681/1000
# 100/100 - 0s - loss: 0.0950 - binary_accuracy: 0.9400
# Epoch 682/1000
# 100/100 - 0s - loss: 0.0894 - binary_accuracy: 0.9400
# Epoch 683/1000
# 100/100 - 0s - loss: 0.0778 - binary_accuracy: 0.9800
# Epoch 684/1000
# 100/100 - 0s - loss: 0.0836 - binary_accuracy: 0.9700
# Epoch 685/1000
# 100/100 - 0s - loss: 0.0797 - binary_accuracy: 0.9700
# Epoch 686/1000
# 100/100 - 0s - loss: 0.0952 - binary_accuracy: 0.9600
# Epoch 687/1000
# 100/100 - 0s - loss: 0.1048 - binary_accuracy: 0.9500
# Epoch 688/1000
# 100/100 - 0s - loss: 0.0952 - binary_accuracy: 0.9500
# Epoch 689/1000
# 100/100 - 0s - loss: 0.0921 - binary_accuracy: 0.9500
# Epoch 690/1000
# 100/100 - 0s - loss: 0.0846 - binary_accuracy: 0.9600
# Epoch 691/1000
# 100/100 - 0s - loss: 0.0828 - binary_accuracy: 0.9600
# Epoch 692/1000
# 100/100 - 0s - loss: 0.0868 - binary_accuracy: 0.9700
# Epoch 693/1000
# 100/100 - 0s - loss: 0.0929 - binary_accuracy: 0.9600
# Epoch 694/1000
# 100/100 - 0s - loss: 0.0894 - binary_accuracy: 0.9600
# Epoch 695/1000
# 100/100 - 0s - loss: 0.0797 - binary_accuracy: 0.9800
# Epoch 696/1000
# 100/100 - 0s - loss: 0.0804 - binary_accuracy: 0.9700
# Epoch 697/1000
# ...
# 100/100 - 0s - loss: 0.0700 - binary_accuracy: 0.9800
# Epoch 770/1000
# 100/100 - 0s - loss: 0.0693 - binary_accuracy: 0.9900
# Epoch 771/1000
# 100/100 - 0s - loss: 0.0681 - binary_accuracy: 0.9900
# Epoch 772/1000
# 100/100 - 0s - loss: 0.0682 - binary_accuracy: 0.9900
# Epoch 773/1000
# 100/100 - 0s - loss: 0.0683 - binary_accuracy: 0.9900
# Epoch 774/1000
# 100/100 - 0s - loss: 0.0691 - binary_accuracy: 0.9800
# Epoch 775/1000
# 100/100 - 0s - loss: 0.0716 - binary_accuracy: 0.9800
# Epoch 776/1000
# 100/100 - 0s - loss: 0.0696 - binary_accuracy: 0.9800
# Epoch 777/1000
# 100/100 - 0s - loss: 0.0687 - binary_accuracy: 0.9800
# Epoch 778/1000
# 100/100 - 0s - loss: 0.0672 - binary_accuracy: 0.9800
# Epoch 779/1000
# 100/100 - 0s - loss: 0.0663 - binary_accuracy: 0.9900
# Epoch 780/1000
# 100/100 - 0s - loss: 0.0663 - binary_accuracy: 0.9900
# Epoch 781/1000
# 100/100 - 0s - loss: 0.0657 - binary_accuracy: 0.9900
# Epoch 782/1000
# 100/100 - 0s - loss: 0.0689 - binary_accuracy: 0.9800
# Epoch 783/1000
# 100/100 - 0s - loss: 0.0639 - binary_accuracy: 0.9900
# Epoch 784/1000
# 100/100 - 0s - loss: 0.0776 - binary_accuracy: 0.9600
# Epoch 785/1000
# 100/100 - 0s - loss: 0.0778 - binary_accuracy: 0.9500
# Epoch 786/1000
# 100/100 - 0s - loss: 0.0697 - binary_accuracy: 0.9800
# Epoch 787/1000
# 100/100 - 0s - loss: 0.0710 - binary_accuracy: 0.9900
# Epoch 788/1000
# 100/100 - 0s - loss: 0.0741 - binary_accuracy: 0.9800
# Epoch 789/1000
# 100/100 - 0s - loss: 0.0704 - binary_accuracy: 0.9800
# Epoch 790/1000
# 100/100 - 0s - loss: 0.0678 - binary_accuracy: 0.9800
# Epoch 791/1000
# 100/100 - 0s - loss: 0.0692 - binary_accuracy: 0.9800
# Epoch 792/1000
# 100/100 - 0s - loss: 0.0670 - binary_accuracy: 0.9800
# Epoch 793/1000
# 100/100 - 0s - loss: 0.0698 - binary_accuracy: 0.9900
# Epoch 794/1000
# 100/100 - 0s - loss: 0.0753 - binary_accuracy: 0.9700
# Epoch 795/1000
# 100/100 - 0s - loss: 0.0722 - binary_accuracy: 0.9800
# Epoch 796/1000
# 100/100 - 0s - loss: 0.0709 - binary_accuracy: 0.9900
# Epoch 797/1000
# 100/100 - 0s - loss: 0.0698 - binary_accuracy: 0.9900
# Epoch 798/1000
# 100/100 - 0s - loss: 0.0786 - binary_accuracy: 0.9600
# Epoch 799/1000
# 100/100 - 0s - loss: 0.0852 - binary_accuracy: 0.9400
# Epoch 800/1000
# 100/100 - 0s - loss: 0.0752 - binary_accuracy: 0.9900
# Epoch 801/1000
# 100/100 - 0s - loss: 0.1268 - binary_accuracy: 0.9400
# Epoch 802/1000
# 100/100 - 0s - loss: 0.1183 - binary_accuracy: 0.9500
# Epoch 803/1000
# 100/100 - 0s - loss: 0.0807 - binary_accuracy: 0.9700
# Epoch 804/1000
# 100/100 - 0s - loss: 0.0890 - binary_accuracy: 0.9600
# Epoch 805/1000
# 100/100 - 0s - loss: 0.1127 - binary_accuracy: 0.9400
# Epoch 806/1000
# 100/100 - 0s - loss: 0.0994 - binary_accuracy: 0.9400
# Epoch 807/1000
# 100/100 - 0s - loss: 0.0774 - binary_accuracy: 0.9600
# Epoch 808/1000
# 100/100 - 0s - loss: 0.0664 - binary_accuracy: 0.9800
# Epoch 809/1000
# 100/100 - 0s - loss: 0.0681 - binary_accuracy: 0.9800
# Epoch 810/1000
# 100/100 - 0s - loss: 0.0698 - binary_accuracy: 0.9800
# Epoch 811/1000
# 100/100 - 0s - loss: 0.0683 - binary_accuracy: 0.9700
# Epoch 812/1000
# 100/100 - 0s - loss: 0.0669 - binary_accuracy: 0.9800
# Epoch 813/1000
# 100/100 - 0s - loss: 0.0655 - binary_accuracy: 0.9900
# Epoch 814/1000
# 100/100 - 0s - loss: 0.0673 - binary_accuracy: 0.9900
# Epoch 815/1000
# 100/100 - 0s - loss: 0.0636 - binary_accuracy: 0.9900
# Epoch 816/1000
# 100/100 - 0s - loss: 0.0660 - binary_accuracy: 0.9900
# Epoch 817/1000
# 100/100 - 0s - loss: 0.0659 - binary_accuracy: 0.9900
# Epoch 818/1000
# 100/100 - 0s - loss: 0.0643 - binary_accuracy: 0.9900
# Epoch 819/1000
# 100/100 - 0s - loss: 0.0632 - binary_accuracy: 0.9900
# Epoch 820/1000
# 100/100 - 0s - loss: 0.0645 - binary_accuracy: 0.9900
# Epoch 821/1000
# 100/100 - 0s - loss: 0.0638 - binary_accuracy: 0.9900
# Epoch 822/1000
# 100/100 - 0s - loss: 0.0645 - binary_accuracy: 0.9900
# Epoch 823/1000
# 100/100 - 0s - loss: 0.0672 - binary_accuracy: 0.9800
# Epoch 824/1000
# 100/100 - 0s - loss: 0.0654 - binary_accuracy: 0.9900
# Epoch 825/1000
# 100/100 - 0s - loss: 0.0641 - binary_accuracy: 0.9900
# Epoch 826/1000
# 100/100 - 0s - loss: 0.0643 - binary_accuracy: 0.9800
# Epoch 827/1000
# 100/100 - 0s - loss: 0.0634 - binary_accuracy: 0.9800
# Epoch 828/1000
# 100/100 - 0s - loss: 0.0629 - binary_accuracy: 0.9800
# Epoch 829/1000
# 100/100 - 0s - loss: 0.0624 - binary_accuracy: 0.9900
# Epoch 830/1000
# 100/100 - 0s - loss: 0.0617 - binary_accuracy: 0.9900
# Epoch 831/1000
# 100/100 - 0s - loss: 0.0615 - binary_accuracy: 0.9900
# Epoch 832/1000
# 100/100 - 0s - loss: 0.0612 - binary_accuracy: 0.9900
# Epoch 833/1000
# 100/100 - 0s - loss: 0.0634 - binary_accuracy: 0.9900
# Epoch 834/1000
# 100/100 - 0s - loss: 0.0633 - binary_accuracy: 0.9900
# Epoch 835/1000
# 100/100 - 0s - loss: 0.0609 - binary_accuracy: 0.9900
# Epoch 836/1000
# 100/100 - 0s - loss: 0.0596 - binary_accuracy: 0.9900
# Epoch 837/1000
# 100/100 - 0s - loss: 0.0680 - binary_accuracy: 0.9900
# Epoch 838/1000
# 100/100 - 0s - loss: 0.0671 - binary_accuracy: 0.9800
# Epoch 839/1000
# 100/100 - 0s - loss: 0.0643 - binary_accuracy: 0.9800
# Epoch 840/1000
# 100/100 - 0s - loss: 0.0636 - binary_accuracy: 0.9800
# Epoch 841/1000
# 100/100 - 0s - loss: 0.0643 - binary_accuracy: 0.9900
# Epoch 842/1000
# 100/100 - 0s - loss: 0.0613 - binary_accuracy: 0.9900
# Epoch 843/1000
# 100/100 - 0s - loss: 0.0595 - binary_accuracy: 0.9900
# Epoch 844/1000
# 100/100 - 0s - loss: 0.0598 - binary_accuracy: 0.9900
# Epoch 845/1000
# 100/100 - 0s - loss: 0.0596 - binary_accuracy: 0.9900
# Epoch 846/1000
# 100/100 - 0s - loss: 0.0607 - binary_accuracy: 0.9900
# Epoch 847/1000
# 100/100 - 0s - loss: 0.0585 - binary_accuracy: 0.9900
# Epoch 848/1000
# 100/100 - 0s - loss: 0.0592 - binary_accuracy: 0.9900
# Epoch 849/1000
# 100/100 - 0s - loss: 0.0612 - binary_accuracy: 0.9900
# Epoch 850/1000
# 100/100 - 0s - loss: 0.0602 - binary_accuracy: 0.9900
# Epoch 851/1000
# 100/100 - 0s - loss: 0.0597 - binary_accuracy: 0.9900
# Epoch 852/1000
# 100/100 - 0s - loss: 0.0614 - binary_accuracy: 0.9900
# Epoch 853/1000
# 100/100 - 0s - loss: 0.0721 - binary_accuracy: 0.9700
# Epoch 854/1000
# 100/100 - 0s - loss: 0.0768 - binary_accuracy: 0.9700
# Epoch 855/1000
# 100/100 - 0s - loss: 0.0812 - binary_accuracy: 0.9700
# Epoch 856/1000
# 100/100 - 0s - loss: 0.0703 - binary_accuracy: 0.9800
# Epoch 857/1000
# 100/100 - 0s - loss: 0.0644 - binary_accuracy: 0.9900
# Epoch 858/1000
# 100/100 - 0s - loss: 0.0613 - binary_accuracy: 0.9900
# Epoch 859/1000
# 100/100 - 0s - loss: 0.0628 - binary_accuracy: 0.9800
# Epoch 860/1000
# 100/100 - 0s - loss: 0.0634 - binary_accuracy: 0.9900
# Epoch 861/1000
# 100/100 - 0s - loss: 0.0700 - binary_accuracy: 0.9800
# Epoch 862/1000
# 100/100 - 0s - loss: 0.0649 - binary_accuracy: 0.9700
# Epoch 863/1000
# 100/100 - 0s - loss: 0.0609 - binary_accuracy: 0.9900
# Epoch 864/1000
# 100/100 - 0s - loss: 0.0659 - binary_accuracy: 0.9800
# Epoch 865/1000
# 100/100 - 0s - loss: 0.0677 - binary_accuracy: 0.9800
# Epoch 866/1000
# 100/100 - 0s - loss: 0.0640 - binary_accuracy: 0.9900
# Epoch 867/1000
# 100/100 - 0s - loss: 0.0627 - binary_accuracy: 0.9900
# Epoch 868/1000
# 100/100 - 0s - loss: 0.0647 - binary_accuracy: 0.9900
# Epoch 869/1000
# 100/100 - 0s - loss: 0.0651 - binary_accuracy: 0.9800
# Epoch 870/1000
# 100/100 - 0s - loss: 0.0634 - binary_accuracy: 0.9800
# Epoch 871/1000
# 100/100 - 0s - loss: 0.0600 - binary_accuracy: 0.9900
# Epoch 872/1000
# 100/100 - 0s - loss: 0.0590 - binary_accuracy: 0.9900
# Epoch 873/1000
# 100/100 - 0s - loss: 0.0584 - binary_accuracy: 0.9900
# Epoch 874/1000
# 100/100 - 0s - loss: 0.0602 - binary_accuracy: 0.9900
# Epoch 875/1000
# 100/100 - 0s - loss: 0.0706 - binary_accuracy: 0.9600
# Epoch 876/1000
# 100/100 - 0s - loss: 0.0726 - binary_accuracy: 0.9600
# Epoch 877/1000
# 100/100 - 0s - loss: 0.0672 - binary_accuracy: 0.9800
# Epoch 878/1000
# 100/100 - 0s - loss: 0.0701 - binary_accuracy: 0.9800
# Epoch 879/1000
# 100/100 - 0s - loss: 0.0676 - binary_accuracy: 0.9800
# Epoch 880/1000
# 100/100 - 0s - loss: 0.0613 - binary_accuracy: 0.9900
# Epoch 881/1000
# 100/100 - 0s - loss: 0.0604 - binary_accuracy: 0.9800
# Epoch 882/1000
# 100/100 - 0s - loss: 0.0630 - binary_accuracy: 0.9700
# Epoch 883/1000
# 100/100 - 0s - loss: 0.0622 - binary_accuracy: 0.9700
# Epoch 884/1000
# 100/100 - 0s - loss: 0.0616 - binary_accuracy: 0.9800
# Epoch 885/1000
# 100/100 - 0s - loss: 0.0592 - binary_accuracy: 0.9800
# Epoch 886/1000
# 100/100 - 0s - loss: 0.0587 - binary_accuracy: 0.9900
# Epoch 887/1000
# 100/100 - 0s - loss: 0.0567 - binary_accuracy: 0.9900
# Epoch 888/1000
# 100/100 - 0s - loss: 0.0561 - binary_accuracy: 0.9900
# Epoch 889/1000
# 100/100 - 0s - loss: 0.0565 - binary_accuracy: 0.9900
# Epoch 890/1000
# 100/100 - 0s - loss: 0.0661 - binary_accuracy: 0.9800
# Epoch 891/1000
# 100/100 - 0s - loss: 0.0585 - binary_accuracy: 0.9900
# Epoch 892/1000
# 100/100 - 0s - loss: 0.0582 - binary_accuracy: 0.9900
# Epoch 893/1000
# 100/100 - 0s - loss: 0.0687 - binary_accuracy: 0.9600
# Epoch 894/1000
# 100/100 - 0s - loss: 0.0704 - binary_accuracy: 0.9600
# Epoch 895/1000
# 100/100 - 0s - loss: 0.0595 - binary_accuracy: 0.9800
# Epoch 896/1000
# 100/100 - 0s - loss: 0.0565 - binary_accuracy: 0.9900
# Epoch 897/1000
# 100/100 - 0s - loss: 0.0573 - binary_accuracy: 0.9900
# Epoch 898/1000
# 100/100 - 0s - loss: 0.0558 - binary_accuracy: 0.9900
# Epoch 899/1000
# 100/100 - 0s - loss: 0.0564 - binary_accuracy: 0.9900
# Epoch 900/1000
# 100/100 - 0s - loss: 0.0549 - binary_accuracy: 0.9900
# Epoch 901/1000
# 100/100 - 0s - loss: 0.0539 - binary_accuracy: 0.9900
# Epoch 902/1000
# 100/100 - 0s - loss: 0.0576 - binary_accuracy: 0.9900
# Epoch 903/1000
# 100/100 - 0s - loss: 0.0587 - binary_accuracy: 0.9900
# Epoch 904/1000
# 100/100 - 0s - loss: 0.0593 - binary_accuracy: 0.9900
# Epoch 905/1000
# 100/100 - 0s - loss: 0.0585 - binary_accuracy: 0.9900
# Epoch 906/1000
# 100/100 - 0s - loss: 0.0560 - binary_accuracy: 0.9900
# Epoch 907/1000
# 100/100 - 0s - loss: 0.0576 - binary_accuracy: 0.9900
# Epoch 908/1000
# 100/100 - 0s - loss: 0.0639 - binary_accuracy: 0.9800
# Epoch 909/1000
# 100/100 - 0s - loss: 0.0635 - binary_accuracy: 0.9800
# Epoch 910/1000
# 100/100 - 0s - loss: 0.0640 - binary_accuracy: 0.9800
# Epoch 911/1000
# 100/100 - 0s - loss: 0.0628 - binary_accuracy: 0.9800
# Epoch 912/1000
# 100/100 - 0s - loss: 0.0608 - binary_accuracy: 0.9800
# Epoch 913/1000
# 100/100 - 0s - loss: 0.0623 - binary_accuracy: 0.9800
# Epoch 914/1000
# 100/100 - 0s - loss: 0.0589 - binary_accuracy: 0.9900
# Epoch 915/1000
# 100/100 - 0s - loss: 0.0596 - binary_accuracy: 0.9900
# Epoch 916/1000
# 100/100 - 0s - loss: 0.0604 - binary_accuracy: 0.9900
# Epoch 917/1000
# 100/100 - 0s - loss: 0.0657 - binary_accuracy: 0.9800
# Epoch 918/1000
# 100/100 - 0s - loss: 0.0615 - binary_accuracy: 0.9900
# Epoch 919/1000
# 100/100 - 0s - loss: 0.0577 - binary_accuracy: 0.9900
# Epoch 920/1000
# 100/100 - 0s - loss: 0.0574 - binary_accuracy: 0.9900
# Epoch 921/1000
# 100/100 - 0s - loss: 0.0561 - binary_accuracy: 0.9900
# Epoch 922/1000
# 100/100 - 0s - loss: 0.0542 - binary_accuracy: 0.9900
# Epoch 923/1000
# 100/100 - 0s - loss: 0.0532 - binary_accuracy: 0.9900
# Epoch 924/1000
# 100/100 - 0s - loss: 0.0538 - binary_accuracy: 0.9900
# Epoch 925/1000
# 100/100 - 0s - loss: 0.0535 - binary_accuracy: 0.9900
# Epoch 926/1000
# 100/100 - 0s - loss: 0.0527 - binary_accuracy: 0.9900
# Epoch 927/1000
# 100/100 - 0s - loss: 0.0526 - binary_accuracy: 0.9900
# Epoch 928/1000
# 100/100 - 0s - loss: 0.0532 - binary_accuracy: 0.9900
# Epoch 929/1000
# 100/100 - 0s - loss: 0.0557 - binary_accuracy: 0.9900
# Epoch 930/1000
# 100/100 - 0s - loss: 0.0567 - binary_accuracy: 0.9800
# Epoch 931/1000
# 100/100 - 0s - loss: 0.0593 - binary_accuracy: 0.9800
# Epoch 932/1000
# 100/100 - 0s - loss: 0.0542 - binary_accuracy: 0.9900
# Epoch 933/1000
# 100/100 - 0s - loss: 0.0523 - binary_accuracy: 0.9900
# Epoch 934/1000
# 100/100 - 0s - loss: 0.0530 - binary_accuracy: 0.9900
# Epoch 935/1000
# 100/100 - 0s - loss: 0.0535 - binary_accuracy: 0.9900
# Epoch 936/1000
# 100/100 - 0s - loss: 0.0529 - binary_accuracy: 0.9900
# Epoch 937/1000
# 100/100 - 0s - loss: 0.0530 - binary_accuracy: 0.9900
# Epoch 938/1000
# 100/100 - 0s - loss: 0.0521 - binary_accuracy: 0.9900
# Epoch 939/1000
# 100/100 - 0s - loss: 0.0521 - binary_accuracy: 0.9900
# Epoch 940/1000
# 100/100 - 0s - loss: 0.0534 - binary_accuracy: 0.9800
# Epoch 941/1000
# 100/100 - 0s - loss: 0.0633 - binary_accuracy: 0.9700
# Epoch 942/1000
# 100/100 - 0s - loss: 0.0607 - binary_accuracy: 0.9700
# Epoch 943/1000
# 100/100 - 0s - loss: 0.0576 - binary_accuracy: 0.9800
# Epoch 944/1000
# 100/100 - 0s - loss: 0.0671 - binary_accuracy: 0.9900
# Epoch 945/1000
# 100/100 - 0s - loss: 0.0629 - binary_accuracy: 0.9900
# Epoch 946/1000
# 100/100 - 0s - loss: 0.0606 - binary_accuracy: 0.9900
# Epoch 947/1000
# 100/100 - 0s - loss: 0.0577 - binary_accuracy: 0.9900
# Epoch 948/1000
# 100/100 - 0s - loss: 0.0533 - binary_accuracy: 0.9900
# Epoch 949/1000
# 100/100 - 0s - loss: 0.0680 - binary_accuracy: 0.9700
# Epoch 950/1000
# 100/100 - 0s - loss: 0.0709 - binary_accuracy: 0.9600
# Epoch 951/1000
# 100/100 - 0s - loss: 0.0590 - binary_accuracy: 0.9800
# Epoch 952/1000
# 100/100 - 0s - loss: 0.0503 - binary_accuracy: 0.9900
# Epoch 953/1000
# 100/100 - 0s - loss: 0.0549 - binary_accuracy: 0.9900
# Epoch 954/1000
# 100/100 - 0s - loss: 0.0626 - binary_accuracy: 0.9800
# Epoch 955/1000
# 100/100 - 0s - loss: 0.0537 - binary_accuracy: 0.9900
# Epoch 956/1000
# 100/100 - 0s - loss: 0.0618 - binary_accuracy: 0.9700
# Epoch 957/1000
# 100/100 - 0s - loss: 0.0548 - binary_accuracy: 0.9900
# Epoch 958/1000
# 100/100 - 0s - loss: 0.0601 - binary_accuracy: 0.9800
# Epoch 959/1000
# 100/100 - 0s - loss: 0.0644 - binary_accuracy: 0.9800
# Epoch 960/1000
# 100/100 - 0s - loss: 0.0587 - binary_accuracy: 0.9900
# Epoch 961/1000
# 100/100 - 0s - loss: 0.0554 - binary_accuracy: 0.9900
# Epoch 962/1000
# 100/100 - 0s - loss: 0.0573 - binary_accuracy: 0.9800
# Epoch 963/1000
# 100/100 - 0s - loss: 0.0572 - binary_accuracy: 0.9800
# Epoch 964/1000
# 100/100 - 0s - loss: 0.0541 - binary_accuracy: 0.9800
# Epoch 965/1000
# 100/100 - 0s - loss: 0.0641 - binary_accuracy: 0.9600
# Epoch 966/1000
# 100/100 - 0s - loss: 0.0683 - binary_accuracy: 0.9700
# Epoch 967/1000
# 100/100 - 0s - loss: 0.0608 - binary_accuracy: 0.9700
# Epoch 968/1000
# 100/100 - 0s - loss: 0.0585 - binary_accuracy: 0.9900
# Epoch 969/1000
# 100/100 - 0s - loss: 0.0603 - binary_accuracy: 0.9900
# Epoch 970/1000
# 100/100 - 0s - loss: 0.0619 - binary_accuracy: 0.9800
# Epoch 971/1000
# 100/100 - 0s - loss: 0.0592 - binary_accuracy: 0.9900
# Epoch 972/1000
# 100/100 - 0s - loss: 0.0568 - binary_accuracy: 0.9800
# Epoch 973/1000
# 100/100 - 0s - loss: 0.0536 - binary_accuracy: 0.9900
# Epoch 974/1000
# 100/100 - 0s - loss: 0.0526 - binary_accuracy: 0.9900
# Epoch 975/1000
# 100/100 - 0s - loss: 0.0529 - binary_accuracy: 0.9900
# Epoch 976/1000
# 100/100 - 0s - loss: 0.0525 - binary_accuracy: 0.9900
# Epoch 977/1000
# 100/100 - 0s - loss: 0.0509 - binary_accuracy: 0.9900
# Epoch 978/1000
# 100/100 - 0s - loss: 0.0531 - binary_accuracy: 0.9900
# Epoch 979/1000
# 100/100 - 0s - loss: 0.0534 - binary_accuracy: 0.9900
# Epoch 980/1000
# 100/100 - 0s - loss: 0.0527 - binary_accuracy: 0.9900
# Epoch 981/1000
# 100/100 - 0s - loss: 0.0517 - binary_accuracy: 0.9900
# Epoch 982/1000
# 100/100 - 0s - loss: 0.0704 - binary_accuracy: 0.9800
# Epoch 983/1000
# 100/100 - 0s - loss: 0.0593 - binary_accuracy: 0.9900
# Epoch 984/1000
# 100/100 - 0s - loss: 0.0590 - binary_accuracy: 0.9800
# Epoch 985/1000
# 100/100 - 0s - loss: 0.0623 - binary_accuracy: 0.9600
# Epoch 986/1000
# 100/100 - 0s - loss: 0.0595 - binary_accuracy: 0.9800
# Epoch 987/1000
# 100/100 - 0s - loss: 0.0508 - binary_accuracy: 0.9900
# Epoch 988/1000
# 100/100 - 0s - loss: 0.0526 - binary_accuracy: 0.9800
# Epoch 989/1000
# 100/100 - 0s - loss: 0.0518 - binary_accuracy: 0.9800
# Epoch 990/1000
# 100/100 - 0s - loss: 0.0501 - binary_accuracy: 0.9900
# Epoch 991/1000
# 100/100 - 0s - loss: 0.0496 - binary_accuracy: 0.9900
# Epoch 992/1000
# 100/100 - 0s - loss: 0.0503 - binary_accuracy: 0.9900
# Epoch 993/1000
# 100/100 - 0s - loss: 0.0548 - binary_accuracy: 0.9900
# Epoch 994/1000
# 100/100 - 0s - loss: 0.0520 - binary_accuracy: 0.9900
# Epoch 995/1000
# 100/100 - 0s - loss: 0.0510 - binary_accuracy: 0.9900
# Epoch 996/1000
# 100/100 - 0s - loss: 0.0504 - binary_accuracy: 0.9900
# Epoch 997/1000
# 100/100 - 0s - loss: 0.0511 - binary_accuracy: 0.9900
# Epoch 998/1000
# 100/100 - 0s - loss: 0.0482 - binary_accuracy: 0.9900
# Epoch 999/1000
# 100/100 - 0s - loss: 0.0496 - binary_accuracy: 0.9900
# Epoch 1000/1000
# 100/100 - 0s - loss: 0.0480 - binary_accuracy: 0.9900

# %% [markdown]
# 한편, keras에서는 `history`함수를 사용해 모델 학습 시 훈련셋, 검증셋의 손실 및 정확도를 측정합니다. 반복횟수에 따른 손실 및 정확도 추이를 보면서 학습 상황을 판단합니다.
#
# 아래 그래프를 보면, `epoch = 1000`으로 설정함에 따라, 1000번 반복하여 모델을 훈련하는 과정에서 손실이 줄어드는 것을 확인할 수 있습니다.

# %%
plt.plot(history.history['loss'])
plt.show()

# %% [markdown]
# 아래 그래프를 보면 1000번을 반복하여 모델을 훈련하는 과정에서 정확도가 올라가는 것을 확인할 수 있습니다.

# %%
plt.plot(history.history['binary_accuracy'])
plt.show()

# %% [markdown]
# ## 4. 결과 확인하기

# %% [markdown]
# 자, 이제 모델을 만들고 학습시켜 보았습니다. `results = model.predict(xs)`를 이용해 만들어진 모델에 데이터를 넣고 결과값을 예측해봅시다. 그래프를 보면, 단순히 직선으로 암 환자와 정상을 구분하지 않고, 다수의 곡선으로 경계가 나뉘어진 것을 확인할 수 있습니다.

# %%
x1s,x2s = np.mgrid[0:1:0.01,0:1:0.01]
xs = np.stack([x1s.ravel(),x2s.ravel()],axis=1)

results = model.predict(xs) # 결과 예측

colors = []
for result in results.ravel():
    if result > 0.5:
        colors.append('r')
    else:
        colors.append('g')
        
fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(1,1,1)
ax.scatter(xs[:,0],xs[:,1],c=colors,alpha=0.1)

# 0: 정상
X[y==1].plot('age','tumor_size',ax=ax,legend=True,
                                   kind='scatter',color='red')
# 1: 암환자
X[y==0].plot('age','tumor_size',ax=ax,legend=True,
                                   kind='scatter',color='green')
plt.legend(["decision",'Cancer','Normal'])
plt.title("Cancer Or Not")
plt.show()

# %% [markdown]
# #
#
# ---
#
#     Copyright(c) 2019 by Public AI. All rights reserved.
#     Writen by PAI, SangJae Kang ( rocketgrowthsj@publicai.co.kr )  last updated on 2019/09/16
#
#
# ---
